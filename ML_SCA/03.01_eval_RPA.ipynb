# %%
# !cp /content/drive/MyDrive/Colab\ Notebooks/include/data_utils.py /content/
#TODO: remove the below 'prerequisites' after cleaning up data_utils
# !cp /content/drive/MyDrive/Colab\ Notebooks/include/tuning_utils.py /content/
# !cp /content/drive/MyDrive/Colab\ Notebooks/include/models.py /content/
# !cp /content/drive/MyDrive/Colab\ Notebooks/include/sca_utils.py /content/
# !cp /content/drive/MyDrive/Colab\ Notebooks/include/data_utils.py /content/
# !pip install keras-tuner --upgrade
# Out:
# Collecting keras-tuner
#   Downloading keras_tuner-1.4.7-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: keras in /usr/local/lib/python3.12/dist-packages (from keras-tuner) (3.10.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from keras-tuner) (25.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from keras-tuner) (2.32.4)
# Collecting kt-legacy (from keras-tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl.metadata (221 bytes)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from keras->keras-tuner) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from keras->keras-tuner) (2.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras->keras-tuner) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras->keras-tuner) (0.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from keras->keras-tuner) (3.14.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras->keras-tuner) (0.17.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.12/dist-packages (from keras->keras-tuner) (0.5.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->keras-tuner) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->keras-tuner) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->keras-tuner) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->keras-tuner) (2025.8.3)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from optree->keras->keras-tuner) (4.15.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras->keras-tuner) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras->keras-tuner) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras->keras-tuner) (0.1.2)
# Downloading keras_tuner-1.4.7-py3-none-any.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 4.5 MB/s eta 0:00:00
# Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.4.7 kt-legacy-1.0.5

# %%
# =========================
# EVAL: VK-calibrate -> FK-attack (robust to probs/logits)
# =========================

# ----- CONFIG -----
BYTE = 15
MODEL = "CBAM" # or "SE"
RUN_DIR = "/content/drive/MyDrive/mbedtls_synthetic_traces/runs_CBAMB15_CBAM_20250907_173132"

# --- Imports ---
import os, numpy as np, tensorflow as tf, matplotlib.pyplot as plt
from data_utils import SyntheticDataLoader
from sca_utils import run_rank_trials, plot_mean_rank

try:
    from models import ChannelwisePool
    CUSTOMS = {"ChannelwisePool": ChannelwisePool}
except Exception:
    CUSTOMS = {}

# --- Sanity: required artifacts from training (VK) ---
need = ["best.keras", "val_logits_labels.npz"]
missing = [f for f in need if not os.path.exists(os.path.join(RUN_DIR, f))]
print("RUN_DIR:", RUN_DIR)
print("Missing:", missing)
assert not missing, f"Missing files in {RUN_DIR}: {missing}"

# --- Load model and VK-val preds/labels ---
model = tf.keras.models.load_model(os.path.join(RUN_DIR, "best.keras"), compile=False, custom_objects=CUSTOMS)
vk_npz = np.load(os.path.join(RUN_DIR, "val_logits_labels.npz"))
vk_pred = vk_npz["logits"] # NOTE: could be *probabilities* if head=softmax, or logits if head=None
vk_lab = vk_npz["labels"] # VK-val labels for *the same target byte*

print("VK-val preds shape:", vk_pred.shape, " VK-val labels shape:", vk_lab.shape)

# --- Helper: numerically stable softmax ---
def softmax_stable(z):
    z = z - np.max(z, axis=1, keepdims=True)
    e = np.exp(z)
    return e / np.sum(e, axis=1, keepdims=True)

# --- Detect if preds look like probabilities or logits ---
def looks_like_prob(P, atol=1e-4):
    row_sums = np.sum(P, axis=1)
    return np.all(np.isfinite(P)) and np.all(P >= -1e-8) and np.all(P <= 1+1e-8) and np.allclose(row_sums, 1.0, atol=atol)

def to_logits(pred):
    """Convert model output to logits:
       - if already logits: return as-is
       - if probabilities: return log(prob) (logit-like)"""
    eps = 1e-12
    if looks_like_prob(pred):
        return np.log(np.clip(pred, eps, 1.0))
    else:
        return pred

# --- Fit temperature on VK-val ONLY (NLL minimization) ---
def fit_temperature(z_val, y_val, steps=60, growth=1.4):
    # simple 1D search around current T
    T = 1.0
    def nll(t):
        P = softmax_stable(z_val / t)
        return -np.mean(np.log(np.clip(P[np.arange(len(y_val)), y_val], 1e-12, 1.0)))
    for _ in range(steps):
        cands = [T / growth, T, T * growth]
        vals = [nll(t) for t in cands]
        T = cands[int(np.argmin(vals))]
    return T

# --- Step 1: compute VK logits (from preds) and fit T ---
z_val = to_logits(vk_pred)
T = fit_temperature(z_val, vk_lab, steps=60, growth=1.4)
print(f"[Calibration] Fitted temperature on VK-val: T = {T:.4f}")

# --- Step 2: load FK attack data and predict ---
H5_ATTK = f"/content/drive/MyDrive/mbedtls_synthetic_traces/RPA_traces/v2_attack_windows/byte_{BYTE}.h5"
att_loader = SyntheticDataLoader(H5_ATTK)
_, ds_att_full, _, _, _ = att_loader.create_dataset(window_index=0, batch_size=256, val_split=1.0)

# Predict on attack
ds_att_X = ds_att_full.map(lambda trace, label, pt, key: trace)
att_pred = model.predict(ds_att_X, verbose=0) # could be probs or logits depending on head

# --- Step 3: build meta (FK), careful with scalar key/plaintext ---
meta = []
for _, _, pt, key in ds_att_full.unbatch():
    k16 = np.zeros(16, np.uint8); k16[BYTE] = key.numpy() if key.shape==() else key.numpy()[BYTE]
    p16 = np.zeros(16, np.uint8); p16[BYTE] = pt.numpy() if pt.shape==() else pt.numpy()[BYTE]
    meta.append({"plaintext": p16, "key": k16})
N_att = len(meta)
print("Attack traces:", N_att)

# --- Step 4: Evaluate WITHOUT temperature (baseline) ---
if looks_like_prob(att_pred):
    P_noT = att_pred
else:
    P_noT = softmax_stable(att_pred) # logits -> probs baseline

steps0, ranks0 = run_rank_trials(
    P_noT, meta,
    n_traces_per_trial=min(1000, N_att),
    n_trials=10, target_byte=BYTE
)
plot_mean_rank(steps0, ranks0)
fig0 = os.path.join(RUN_DIR, f"rank_attack_noT_b{BYTE}_{MODEL}.png")
plt.savefig(fig0, dpi=200, bbox_inches='tight')
print("Saved (no T):", fig0)

# --- Step 5: Evaluate WITH temperature ---
z_att = to_logits(att_pred)
P_T = softmax_stable(z_att / T)

stepsT, ranksT = run_rank_trials(
    P_T, meta,
    n_traces_per_trial=min(1000, N_att),
    n_trials=10, target_byte=BYTE
)
plot_mean_rank(stepsT, ranksT)
figT = os.path.join(RUN_DIR, f"rank_attack_withT_b{BYTE}_{MODEL}.png")
plt.savefig(figT, dpi=200, bbox_inches='tight')
print("Saved (with T):", figT)

# --- Diagnostics ---
print("\n[Diagnostics]")
print("VK logits (min,max,mean):", np.min(z_val), np.max(z_val), np.mean(z_val))
print("ATT logits (min,max,mean):", np.min(z_att), np.max(z_att), np.mean(z_att))
print("looks_like_prob(VK preds):", looks_like_prob(vk_pred))
print("looks_like_prob(ATT preds):", looks_like_prob(att_pred))
# Out:
# RUN_DIR: /content/drive/MyDrive/mbedtls_synthetic_traces/runs_CBAMB15_CBAM_20250907_173132
# Missing: []
# VK-val preds shape: (1200, 256)  VK-val labels shape: (1200,)
# [Calibration] Fitted temperature on VK-val: T = 24201.4324
# Dataset created from 'byte_15.h5':
#   - Total samples: 3001
#   - Training samples: 0
#   - Validation samples: 3001
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:160: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# Attack traces: 3001
# Trials:   0%|          | 0/10 [00:00<?, ?it/s]
# Rank steps (Trial 1):   0%|          | 0/100 [00:00<?, ?it/s]
# Rank steps (Trial 1):   4%|▍         | 4/100 [00:00<00:03, 31.95it/s]
# Rank steps (Trial 1):   8%|▊         | 8/100 [00:00<00:05, 17.48it/s]
# Rank steps (Trial 1):  11%|█         | 11/100 [00:00<00:06, 12.90it/s]
# Rank steps (Trial 1):  13%|█▎        | 13/100 [00:01<00:07, 10.92it/s]
# Rank steps (Trial 1):  15%|█▌        | 15/100 [00:01<00:09,  9.03it/s]
# Rank steps (Trial 1):  17%|█▋        | 17/100 [00:01<00:11,  7.52it/s]
# Rank steps (Trial 1):  18%|█▊        | 18/100 [00:01<00:11,  6.96it/s]
# Rank steps (Trial 1):  19%|█▉        | 19/100 [00:02<00:12,  6.43it/s]
# Rank steps (Trial 1):  20%|██        | 20/100 [00:02<00:13,  6.15it/s]
# Rank steps (Trial 1):  21%|██        | 21/100 [00:02<00:12,  6.54it/s]
# Rank steps (Trial 1):  22%|██▏       | 22/100 [00:02<00:11,  6.59it/s]
# Rank steps (Trial 1):  23%|██▎       | 23/100 [00:02<00:11,  6.79it/s]
# Rank steps (Trial 1):  24%|██▍       | 24/100 [00:02<00:11,  6.88it/s]
# Rank steps (Trial 1):  25%|██▌       | 25/100 [00:02<00:10,  6.89it/s]
# Rank steps (Trial 1):  26%|██▌       | 26/100 [00:03<00:10,  6.75it/s]
# Rank steps (Trial 1):  27%|██▋       | 27/100 [00:03<00:10,  6.66it/s]
# Rank steps (Trial 1):  28%|██▊       | 28/100 [00:03<00:11,  6.50it/s]
# Rank steps (Trial 1):  29%|██▉       | 29/100 [00:03<00:11,  6.10it/s]
# Rank steps (Trial 1):  30%|███       | 30/100 [00:03<00:11,  6.02it/s]
# Rank steps (Trial 1):  31%|███       | 31/100 [00:04<00:11,  5.92it/s]
# Rank steps (Trial 1):  32%|███▏      | 32/100 [00:04<00:11,  5.71it/s]
# Rank steps (Trial 1):  33%|███▎      | 33/100 [00:04<00:12,  5.53it/s]
# Rank steps (Trial 1):  34%|███▍      | 34/100 [00:04<00:12,  5.32it/s]
# Rank steps (Trial 1):  35%|███▌      | 35/100 [00:04<00:12,  5.01it/s]
# Rank steps (Trial 1):  36%|███▌      | 36/100 [00:05<00:13,  4.92it/s]
# Rank steps (Trial 1):  37%|███▋      | 37/100 [00:05<00:13,  4.81it/s]
# Rank steps (Trial 1):  38%|███▊      | 38/100 [00:05<00:13,  4.76it/s]
# Rank steps (Trial 1):  39%|███▉      | 39/100 [00:05<00:13,  4.53it/s]
# Rank steps (Trial 1):  40%|████      | 40/100 [00:05<00:13,  4.46it/s]
# Rank steps (Trial 1):  41%|████      | 41/100 [00:06<00:13,  4.27it/s]
# Rank steps (Trial 1):  42%|████▏     | 42/100 [00:06<00:13,  4.20it/s]
# Rank steps (Trial 1):  43%|████▎     | 43/100 [00:06<00:14,  4.04it/s]
# Rank steps (Trial 1):  44%|████▍     | 44/100 [00:07<00:14,  3.78it/s]
# Rank steps (Trial 1):  45%|████▌     | 45/100 [00:07<00:15,  3.53it/s]
# Rank steps (Trial 1):  46%|████▌     | 46/100 [00:07<00:15,  3.58it/s]
# Rank steps (Trial 1):  47%|████▋     | 47/100 [00:07<00:15,  3.50it/s]
# Rank steps (Trial 1):  48%|████▊     | 48/100 [00:08<00:14,  3.54it/s]
# Rank steps (Trial 1):  49%|████▉     | 49/100 [00:08<00:14,  3.54it/s]
# Rank steps (Trial 1):  50%|█████     | 50/100 [00:08<00:14,  3.54it/s]
# Rank steps (Trial 1):  51%|█████     | 51/100 [00:09<00:14,  3.43it/s]
# Rank steps (Trial 1):  52%|█████▏    | 52/100 [00:09<00:14,  3.40it/s]
# Rank steps (Trial 1):  53%|█████▎    | 53/100 [00:09<00:13,  3.37it/s]
# Rank steps (Trial 1):  54%|█████▍    | 54/100 [00:10<00:14,  3.26it/s]
# Rank steps (Trial 1):  55%|█████▌    | 55/100 [00:10<00:13,  3.23it/s]
# Rank steps (Trial 1):  56%|█████▌    | 56/100 [00:10<00:13,  3.16it/s]
# Rank steps (Trial 1):  57%|█████▋    | 57/100 [00:10<00:13,  3.08it/s]
# Rank steps (Trial 1):  58%|█████▊    | 58/100 [00:11<00:14,  2.98it/s]
# Rank steps (Trial 1):  59%|█████▉    | 59/100 [00:11<00:13,  2.96it/s]
# Rank steps (Trial 1):  60%|██████    | 60/100 [00:12<00:13,  2.91it/s]
# Rank steps (Trial 1):  61%|██████    | 61/100 [00:12<00:15,  2.60it/s]
# Rank steps (Trial 1):  62%|██████▏   | 62/100 [00:13<00:17,  2.15it/s]
# Rank steps (Trial 1):  63%|██████▎   | 63/100 [00:13<00:19,  1.93it/s]
# Rank steps (Trial 1):  64%|██████▍   | 64/100 [00:14<00:20,  1.76it/s]
# Rank steps (Trial 1):  65%|██████▌   | 65/100 [00:15<00:21,  1.65it/s]
# Rank steps (Trial 1):  66%|██████▌   | 66/100 [00:15<00:21,  1.59it/s]
# Rank steps (Trial 1):  67%|██████▋   | 67/100 [00:16<00:21,  1.56it/s]
# Rank steps (Trial 1):  68%|██████▊   | 68/100 [00:16<00:18,  1.77it/s]
# Rank steps (Trial 1):  69%|██████▉   | 69/100 [00:17<00:16,  1.93it/s]
# Rank steps (Trial 1):  70%|███████   | 70/100 [00:17<00:14,  2.08it/s]
# Rank steps (Trial 1):  71%|███████   | 71/100 [00:18<00:13,  2.17it/s]
# Rank steps (Trial 1):  72%|███████▏  | 72/100 [00:18<00:12,  2.21it/s]
# Rank steps (Trial 1):  73%|███████▎  | 73/100 [00:19<00:11,  2.26it/s]
# Rank steps (Trial 1):  74%|███████▍  | 74/100 [00:19<00:11,  2.24it/s]
# Rank steps (Trial 1):  75%|███████▌  | 75/100 [00:19<00:11,  2.21it/s]
# Rank steps (Trial 1):  76%|███████▌  | 76/100 [00:20<00:10,  2.24it/s]
# Rank steps (Trial 1):  77%|███████▋  | 77/100 [00:20<00:10,  2.23it/s]
# Rank steps (Trial 1):  78%|███████▊  | 78/100 [00:21<00:09,  2.24it/s]
# Rank steps (Trial 1):  79%|███████▉  | 79/100 [00:21<00:09,  2.20it/s]
# Rank steps (Trial 1):  80%|████████  | 80/100 [00:22<00:09,  2.07it/s]
# Rank steps (Trial 1):  81%|████████  | 81/100 [00:22<00:09,  2.08it/s]
# Rank steps (Trial 1):  82%|████████▏ | 82/100 [00:23<00:08,  2.09it/s]
# Rank steps (Trial 1):  83%|████████▎ | 83/100 [00:23<00:08,  2.01it/s]
# Rank steps (Trial 1):  84%|████████▍ | 84/100 [00:24<00:07,  2.03it/s]
# Rank steps (Trial 1):  85%|████████▌ | 85/100 [00:24<00:07,  2.02it/s]
# Rank steps (Trial 1):  86%|████████▌ | 86/100 [00:25<00:06,  2.03it/s]
# Rank steps (Trial 1):  87%|████████▋ | 87/100 [00:25<00:06,  2.02it/s]
# Rank steps (Trial 1):  88%|████████▊ | 88/100 [00:26<00:06,  1.99it/s]
# Rank steps (Trial 1):  89%|████████▉ | 89/100 [00:27<00:06,  1.68it/s]
# Rank steps (Trial 1):  90%|█████████ | 90/100 [00:28<00:07,  1.42it/s]
# Rank steps (Trial 1):  91%|█████████ | 91/100 [00:29<00:07,  1.27it/s]
# Rank steps (Trial 1):  92%|█████████▏| 92/100 [00:29<00:06,  1.20it/s]
# Rank steps (Trial 1):  93%|█████████▎| 93/100 [00:30<00:05,  1.19it/s]
# Rank steps (Trial 1):  94%|█████████▍| 94/100 [00:31<00:04,  1.31it/s]
# Rank steps (Trial 1):  95%|█████████▌| 95/100 [00:31<00:03,  1.43it/s]
# Rank steps (Trial 1):  96%|█████████▌| 96/100 [00:32<00:02,  1.46it/s]
# Rank steps (Trial 1):  97%|█████████▋| 97/100 [00:33<00:01,  1.54it/s]
# Rank steps (Trial 1):  98%|█████████▊| 98/100 [00:33<00:01,  1.61it/s]
# Rank steps (Trial 1):  99%|█████████▉| 99/100 [00:34<00:00,  1.63it/s]
# Rank steps (Trial 1): 100%|██████████| 100/100 [00:34<00:00,  1.68it/s]
# Trials:  10%|█         | 1/10 [00:34<05:14, 34.90s/it]
# Rank steps (Trial 2):   0%|          | 0/100 [00:00<?, ?it/s]
# Rank steps (Trial 2):   6%|▌         | 6/100 [00:00<00:01, 47.98it/s]
# Rank steps (Trial 2):  11%|█         | 11/100 [00:00<00:03, 25.03it/s]
# Rank steps (Trial 2):  15%|█▌        | 15/100 [00:00<00:04, 18.32it/s]
# Rank steps (Trial 2):  18%|█▊        | 18/100 [00:01<00:05, 15.04it/s]
# Rank steps (Trial 2):  20%|██        | 20/100 [00:01<00:06, 13.18it/s]
# Rank steps (Trial 2):  22%|██▏       | 22/100 [00:01<00:06, 11.23it/s]
# Rank steps (Trial 2):  24%|██▍       | 24/100 [00:01<00:07,  9.94it/s]
# Rank steps (Trial 2):  26%|██▌       | 26/100 [00:02<00:08,  8.92it/s]
# Rank steps (Trial 2):  27%|██▋       | 27/100 [00:02<00:08,  8.35it/s]
# Rank steps (Trial 2):  28%|██▊       | 28/100 [00:02<00:09,  7.62it/s]
# Rank steps (Trial 2):  29%|██▉       | 29/100 [00:02<00:10,  7.03it/s]
# Rank steps (Trial 2):  30%|███       | 30/100 [00:02<00:10,  6.68it/s]
# Rank steps (Trial 2):  31%|███       | 31/100 [00:02<00:10,  6.37it/s]
# Rank steps (Trial 2):  32%|███▏      | 32/100 [00:03<00:11,  6.13it/s]
# Rank steps (Trial 2):  33%|███▎      | 33/100 [00:03<00:11,  5.87it/s]
# Rank steps (Trial 2):  34%|███▍      | 34/100 [00:03<00:12,  5.45it/s]
# Rank steps (Trial 2):  35%|███▌      | 35/100 [00:03<00:12,  5.29it/s]
# Rank steps (Trial 2):  36%|███▌      | 36/100 [00:03<00:12,  5.16it/s]
# Rank steps (Trial 2):  37%|███▋      | 37/100 [00:04<00:12,  5.03it/s]
# Rank steps (Trial 2):  38%|███▊      | 38/100 [00:04<00:12,  4.88it/s]
# Rank steps (Trial 2):  39%|███▉      | 39/100 [00:04<00:13,  4.64it/s]
# Rank steps (Trial 2):  40%|████      | 40/100 [00:04<00:13,  4.54it/s]
# Rank steps (Trial 2):  41%|████      | 41/100 [00:05<00:13,  4.44it/s]
# Rank steps (Trial 2):  42%|████▏     | 42/100 [00:05<00:13,  4.30it/s]
# Rank steps (Trial 2):  43%|████▎     | 43/100 [00:05<00:13,  4.13it/s]
# Rank steps (Trial 2):  44%|████▍     | 44/100 [00:05<00:14,  3.93it/s]
# Rank steps (Trial 2):  45%|████▌     | 45/100 [00:06<00:17,  3.11it/s]
# Rank steps (Trial 2):  46%|████▌     | 46/100 [00:06<00:20,  2.62it/s]
# Rank steps (Trial 2):  47%|████▋     | 47/100 [00:07<00:22,  2.31it/s]
# Rank steps (Trial 2):  48%|████▊     | 48/100 [00:08<00:24,  2.09it/s]
# Rank steps (Trial 2):  49%|████▉     | 49/100 [00:08<00:25,  2.01it/s]
# Rank steps (Trial 2):  50%|█████     | 50/100 [00:09<00:25,  1.99it/s]
# Rank steps (Trial 2):  51%|█████     | 51/100 [00:09<00:25,  1.94it/s]
# Rank steps (Trial 2):  52%|█████▏    | 52/100 [00:10<00:25,  1.91it/s]
# Rank steps (Trial 2):  53%|█████▎    | 53/100 [00:10<00:21,  2.18it/s]
# Rank steps (Trial 2):  54%|█████▍    | 54/100 [00:10<00:19,  2.40it/s]
# Rank steps (Trial 2):  55%|█████▌    | 55/100 [00:11<00:17,  2.56it/s]
# Rank steps (Trial 2):  56%|█████▌    | 56/100 [00:11<00:16,  2.72it/s]
# Rank steps (Trial 2):  57%|█████▋    | 57/100 [00:11<00:15,  2.81it/s]
# Rank steps (Trial 2):  58%|█████▊    | 58/100 [00:12<00:14,  2.83it/s]
# Rank steps (Trial 2):  59%|█████▉    | 59/100 [00:12<00:14,  2.84it/s]
# Rank steps (Trial 2):  60%|██████    | 60/100 [00:12<00:13,  2.87it/s]
# Rank steps (Trial 2):  61%|██████    | 61/100 [00:13<00:13,  2.82it/s]
# Rank steps (Trial 2):  62%|██████▏   | 62/100 [00:13<00:13,  2.81it/s]
# Rank steps (Trial 2):  63%|██████▎   | 63/100 [00:13<00:13,  2.81it/s]
# Rank steps (Trial 2):  64%|██████▍   | 64/100 [00:14<00:13,  2.69it/s]
# Rank steps (Trial 2):  65%|██████▌   | 65/100 [00:14<00:12,  2.69it/s]
# Rank steps (Trial 2):  66%|██████▌   | 66/100 [00:15<00:13,  2.61it/s]
# Rank steps (Trial 2):  67%|██████▋   | 67/100 [00:15<00:12,  2.57it/s]
# Rank steps (Trial 2):  68%|██████▊   | 68/100 [00:15<00:12,  2.54it/s]
# Rank steps (Trial 2):  69%|██████▉   | 69/100 [00:16<00:12,  2.46it/s]
# Rank steps (Trial 2):  70%|███████   | 70/100 [00:16<00:12,  2.46it/s]
# Rank steps (Trial 2):  71%|███████   | 71/100 [00:17<00:11,  2.44it/s]
# Rank steps (Trial 2):  72%|███████▏  | 72/100 [00:17<00:12,  2.28it/s]
# Rank steps (Trial 2):  73%|███████▎  | 73/100 [00:18<00:11,  2.27it/s]
# Rank steps (Trial 2):  74%|███████▍  | 74/100 [00:18<00:11,  2.27it/s]
# Rank steps (Trial 2):  75%|███████▌  | 75/100 [00:18<00:10,  2.29it/s]
# Rank steps (Trial 2):  76%|███████▌  | 76/100 [00:19<00:10,  2.24it/s]
# Rank steps (Trial 2):  77%|███████▋  | 77/100 [00:19<00:10,  2.24it/s]
# Rank steps (Trial 2):  78%|███████▊  | 78/100 [00:20<00:10,  2.08it/s]
# Rank steps (Trial 2):  79%|███████▉  | 79/100 [00:21<00:12,  1.71it/s]
# Rank steps (Trial 2):  80%|████████  | 80/100 [00:22<00:13,  1.51it/s]
# Rank steps (Trial 2):  81%|████████  | 81/100 [00:22<00:13,  1.38it/s]
# Rank steps (Trial 2):  82%|████████▏ | 82/100 [00:23<00:13,  1.31it/s]
# Rank steps (Trial 2):  83%|████████▎ | 83/100 [00:24<00:12,  1.33it/s]
# Rank steps (Trial 2):  84%|████████▍ | 84/100 [00:25<00:10,  1.48it/s]
# Rank steps (Trial 2):  85%|████████▌ | 85/100 [00:25<00:09,  1.62it/s]
# Rank steps (Trial 2):  86%|████████▌ | 86/100 [00:26<00:08,  1.70it/s]
# Rank steps (Trial 2):  87%|████████▋ | 87/100 [00:26<00:07,  1.79it/s]
# Rank steps (Trial 2):  88%|████████▊ | 88/100 [00:27<00:06,  1.83it/s]
# Rank steps (Trial 2):  89%|████████▉ | 89/100 [00:27<00:05,  1.85it/s]
# Rank steps (Trial 2):  90%|█████████ | 90/100 [00:28<00:05,  1.76it/s]
# Rank steps (Trial 2):  91%|█████████ | 91/100 [00:28<00:04,  1.81it/s]
# Rank steps (Trial 2):  92%|█████████▏| 92/100 [00:29<00:04,  1.82it/s]
# Rank steps (Trial 2):  93%|█████████▎| 93/100 [00:29<00:03,  1.82it/s]
# Rank steps (Trial 2):  94%|█████████▍| 94/100 [00:30<00:03,  1.81it/s]
# Rank steps (Trial 2):  95%|█████████▌| 95/100 [00:30<00:02,  1.80it/s]
# Rank steps (Trial 2):  96%|█████████▌| 96/100 [00:31<00:02,  1.79it/s]
# Rank steps (Trial 2):  97%|█████████▋| 97/100 [00:32<00:01,  1.78it/s]
# Rank steps (Trial 2):  98%|█████████▊| 98/100 [00:32<00:01,  1.79it/s]
# Rank steps (Trial 2):  99%|█████████▉| 99/100 [00:33<00:00,  1.76it/s]
# Rank steps (Trial 2): 100%|██████████| 100/100 [00:33<00:00,  1.75it/s]
# Trials:  20%|██        | 2/10 [01:08<04:34, 34.25s/it]
# Rank steps (Trial 3):   0%|          | 0/100 [00:00<?, ?it/s]
# Rank steps (Trial 3):   6%|▌         | 6/100 [00:00<00:02, 46.73it/s]
# Rank steps (Trial 3):  11%|█         | 11/100 [00:00<00:03, 24.78it/s]
# Rank steps (Trial 3):  14%|█▍        | 14/100 [00:00<00:05, 17.09it/s]
# Rank steps (Trial 3):  17%|█▋        | 17/100 [00:01<00:07, 10.66it/s]
# Rank steps (Trial 3):  19%|█▉        | 19/100 [00:01<00:09,  8.44it/s]
# Rank steps (Trial 3):  21%|██        | 21/100 [00:02<00:11,  6.93it/s]
# Rank steps (Trial 3):  22%|██▏       | 22/100 [00:02<00:12,  6.28it/s]
# Rank steps (Trial 3):  23%|██▎       | 23/100 [00:02<00:13,  5.67it/s]
# Rank steps (Trial 3):  24%|██▍       | 24/100 [00:02<00:14,  5.14it/s]
# Rank steps (Trial 3):  25%|██▌       | 25/100 [00:03<00:16,  4.66it/s]
# Rank steps (Trial 3):  26%|██▌       | 26/100 [00:03<00:16,  4.38it/s]
# Rank steps (Trial 3):  27%|██▋       | 27/100 [00:03<00:17,  4.14it/s]
# Rank steps (Trial 3):  28%|██▊       | 28/100 [00:03<00:18,  3.92it/s]
# Rank steps (Trial 3):  29%|██▉       | 29/100 [00:04<00:21,  3.38it/s]
# Rank steps (Trial 3):  30%|███       | 30/100 [00:04<00:21,  3.22it/s]
# Rank steps (Trial 3):  31%|███       | 31/100 [00:05<00:22,  3.13it/s]
# Rank steps (Trial 3):  32%|███▏      | 32/100 [00:05<00:19,  3.54it/s]
# Rank steps (Trial 3):  33%|███▎      | 33/100 [00:05<00:17,  3.84it/s]
# Rank steps (Trial 3):  34%|███▍      | 34/100 [00:05<00:16,  4.04it/s]
# Rank steps (Trial 3):  35%|███▌      | 35/100 [00:05<00:15,  4.27it/s]
# Rank steps (Trial 3):  36%|███▌      | 36/100 [00:06<00:14,  4.39it/s]
# Rank steps (Trial 3):  37%|███▋      | 37/100 [00:06<00:14,  4.47it/s]
# Rank steps (Trial 3):  38%|███▊      | 38/100 [00:06<00:13,  4.48it/s]
# Rank steps (Trial 3):  39%|███▉      | 39/100 [00:06<00:14,  4.34it/s]
# Rank steps (Trial 3):  40%|████      | 40/100 [00:07<00:13,  4.32it/s]
# Rank steps (Trial 3):  41%|████      | 41/100 [00:07<00:13,  4.25it/s]
# Rank steps (Trial 3):  42%|████▏     | 42/100 [00:07<00:13,  4.21it/s]
# Rank steps (Trial 3):  43%|████▎     | 43/100 [00:07<00:14,  4.04it/s]
# Rank steps (Trial 3):  44%|████▍     | 44/100 [00:08<00:14,  3.98it/s]
# Rank steps (Trial 3):  45%|████▌     | 45/100 [00:08<00:13,  3.95it/s]
# Rank steps (Trial 3):  46%|████▌     | 46/100 [00:08<00:13,  3.88it/s]
# Rank steps (Trial 3):  47%|████▋     | 47/100 [00:08<00:14,  3.72it/s]
# Rank steps (Trial 3):  48%|████▊     | 48/100 [00:09<00:14,  3.69it/s]
# Rank steps (Trial 3):  49%|████▉     | 49/100 [00:09<00:13,  3.66it/s]
# Rank steps (Trial 3):  50%|█████     | 50/100 [00:09<00:13,  3.61it/s]
# Rank steps (Trial 3):  51%|█████     | 51/100 [00:09<00:14,  3.48it/s]
# Rank steps (Trial 3):  52%|█████▏    | 52/100 [00:10<00:13,  3.43it/s]
# Rank steps (Trial 3):  53%|█████▎    | 53/100 [00:10<00:13,  3.40it/s]
# Rank steps (Trial 3):  54%|█████▍    | 54/100 [00:10<00:14,  3.26it/s]
# Rank steps (Trial 3):  55%|█████▌    | 55/100 [00:11<00:14,  3.12it/s]
# Rank steps (Trial 3):  56%|█████▌    | 56/100 [00:11<00:14,  3.13it/s]
# Rank steps (Trial 3):  57%|█████▋    | 57/100 [00:11<00:14,  3.04it/s]
# Rank steps (Trial 3):  58%|█████▊    | 58/100 [00:12<00:13,  3.03it/s]
# Rank steps (Trial 3):  59%|█████▉    | 59/100 [00:12<00:13,  3.03it/s]
# Rank steps (Trial 3):  60%|██████    | 60/100 [00:12<00:13,  2.94it/s]
# Rank steps (Trial 3):  61%|██████    | 61/100 [00:13<00:13,  2.87it/s]
# Rank steps (Trial 3):  62%|██████▏   | 62/100 [00:13<00:13,  2.86it/s]
# Rank steps (Trial 3):  63%|██████▎   | 63/100 [00:14<00:13,  2.73it/s]
# Rank steps (Trial 3):  64%|██████▍   | 64/100 [00:14<00:13,  2.58it/s]
# Rank steps (Trial 3):  65%|██████▌   | 65/100 [00:14<00:13,  2.57it/s]
# Rank steps (Trial 3):  66%|██████▌   | 66/100 [00:15<00:16,  2.11it/s]
# Rank steps (Trial 3):  67%|██████▋   | 67/100 [00:16<00:17,  1.84it/s]
# Rank steps (Trial 3):  68%|██████▊   | 68/100 [00:17<00:19,  1.67it/s]
# Rank steps (Trial 3):  69%|██████▉   | 69/100 [00:17<00:19,  1.57it/s]
# Rank steps (Trial 3):  70%|███████   | 70/100 [00:18<00:20,  1.49it/s]
# Rank steps (Trial 3):  71%|███████   | 71/100 [00:19<00:19,  1.46it/s]
# Rank steps (Trial 3):  72%|███████▏  | 72/100 [00:19<00:17,  1.64it/s]
# Rank steps (Trial 3):  73%|███████▎  | 73/100 [00:20<00:14,  1.81it/s]
# Rank steps (Trial 3):  74%|███████▍  | 74/100 [00:20<00:13,  1.93it/s]
# Rank steps (Trial 3):  75%|███████▌  | 75/100 [00:20<00:12,  2.04it/s]
# Rank steps (Trial 3):  76%|███████▌  | 76/100 [00:21<00:11,  2.09it/s]
# Rank steps (Trial 3):  77%|███████▋  | 77/100 [00:21<00:10,  2.12it/s]
# Rank steps (Trial 3):  78%|███████▊  | 78/100 [00:22<00:10,  2.16it/s]
# Rank steps (Trial 3):  79%|███████▉  | 79/100 [00:22<00:09,  2.15it/s]
# Rank steps (Trial 3):  80%|████████  | 80/100 [00:23<00:09,  2.14it/s]
# Rank steps (Trial 3):  81%|████████  | 81/100 [00:23<00:08,  2.13it/s]
# Rank steps (Trial 3):  82%|████████▏ | 82/100 [00:24<00:08,  2.13it/s]
# Rank steps (Trial 3):  83%|████████▎ | 83/100 [00:24<00:08,  2.08it/s]
# Rank steps (Trial 3):  84%|████████▍ | 84/100 [00:25<00:07,  2.09it/s]
# Rank steps (Trial 3):  85%|████████▌ | 85/100 [00:25<00:07,  2.05it/s]
# Rank steps (Trial 3):  86%|████████▌ | 86/100 [00:26<00:06,  2.05it/s]
# Rank steps (Trial 3):  87%|████████▋ | 87/100 [00:26<00:06,  2.02it/s]
# Rank steps (Trial 3):  88%|████████▊ | 88/100 [00:27<00:05,  2.01it/s]
# Rank steps (Trial 3):  89%|████████▉ | 89/100 [00:27<00:05,  1.98it/s]
# Rank steps (Trial 3):  90%|█████████ | 90/100 [00:28<00:05,  1.98it/s]
# Rank steps (Trial 3):  91%|█████████ | 91/100 [00:28<00:04,  1.95it/s]
# Rank steps (Trial 3):  92%|█████████▏| 92/100 [00:29<00:04,  1.75it/s]
# Rank steps (Trial 3):  93%|█████████▎| 93/100 [00:30<00:04,  1.44it/s]
# Rank steps (Trial 3):  94%|█████████▍| 94/100 [00:31<00:04,  1.27it/s]
# Rank steps (Trial 3):  95%|█████████▌| 95/100 [00:32<00:04,  1.18it/s]
# Rank steps (Trial 3):  96%|█████████▌| 96/100 [00:33<00:03,  1.11it/s]
# Rank steps (Trial 3):  97%|█████████▋| 97/100 [00:33<00:02,  1.26it/s]
# Rank steps (Trial 3):  98%|█████████▊| 98/100 [00:34<00:01,  1.37it/s]
# Rank steps (Trial 3):  99%|█████████▉| 99/100 [00:35<00:00,  1.39it/s]
# Rank steps (Trial 3): 100%|██████████| 100/100 [00:35<00:00,  1.48it/s]
# Trials:  30%|███       | 3/10 [01:44<04:04, 34.99s/it]
# Rank steps (Trial 4):   0%|          | 0/100 [00:00<?, ?it/s]
# Rank steps (Trial 4):   6%|▌         | 6/100 [00:00<00:01, 47.11it/s]
# Rank steps (Trial 4):  11%|█         | 11/100 [00:00<00:03, 24.86it/s]
# Rank steps (Trial 4):  14%|█▍        | 14/100 [00:00<00:04, 19.29it/s]
# Rank steps (Trial 4):  17%|█▋        | 17/100 [00:00<00:05, 15.31it/s]
# Rank steps (Trial 4):  19%|█▉        | 19/100 [00:01<00:06, 13.20it/s]
# Rank steps (Trial 4):  21%|██        | 21/100 [00:01<00:07, 11.25it/s]
# Rank steps (Trial 4):  23%|██▎       | 23/100 [00:01<00:07, 10.08it/s]
# Rank steps (Trial 4):  25%|██▌       | 25/100 [00:01<00:08,  9.07it/s]
# Rank steps (Trial 4):  26%|██▌       | 26/100 [00:02<00:08,  8.51it/s]
# Rank steps (Trial 4):  27%|██▋       | 27/100 [00:02<00:09,  7.94it/s]
# Rank steps (Trial 4):  28%|██▊       | 28/100 [00:02<00:09,  7.28it/s]
# Rank steps (Trial 4):  29%|██▉       | 29/100 [00:02<00:10,  6.82it/s]
# Rank steps (Trial 4):  30%|███       | 30/100 [00:02<00:11,  6.34it/s]
# Rank steps (Trial 4):  31%|███       | 31/100 [00:02<00:11,  6.14it/s]
# Rank steps (Trial 4):  32%|███▏      | 32/100 [00:03<00:11,  5.91it/s]
# Rank steps (Trial 4):  33%|███▎      | 33/100 [00:03<00:11,  5.68it/s]
# Rank steps (Trial 4):  34%|███▍      | 34/100 [00:03<00:12,  5.38it/s]
# Rank steps (Trial 4):  35%|███▌      | 35/100 [00:03<00:12,  5.28it/s]
# Rank steps (Trial 4):  36%|███▌      | 36/100 [00:03<00:12,  5.11it/s]
# Rank steps (Trial 4):  37%|███▋      | 37/100 [00:04<00:12,  4.94it/s]
# Rank steps (Trial 4):  38%|███▊      | 38/100 [00:04<00:13,  4.73it/s]
# Rank steps (Trial 4):  39%|███▉      | 39/100 [00:04<00:13,  4.53it/s]
# Rank steps (Trial 4):  40%|████      | 40/100 [00:04<00:13,  4.50it/s]
# Rank steps (Trial 4):  41%|████      | 41/100 [00:05<00:13,  4.37it/s]
# Rank steps (Trial 4):  42%|████▏     | 42/100 [00:05<00:14,  4.04it/s]
# Rank steps (Trial 4):  43%|████▎     | 43/100 [00:05<00:14,  3.90it/s]
# Rank steps (Trial 4):  44%|████▍     | 44/100 [00:05<00:14,  3.92it/s]
# Rank steps (Trial 4):  45%|████▌     | 45/100 [00:06<00:14,  3.90it/s]
# Rank steps (Trial 4):  46%|████▌     | 46/100 [00:06<00:13,  3.88it/s]
# Rank steps (Trial 4):  47%|████▋     | 47/100 [00:06<00:14,  3.74it/s]
# Rank steps (Trial 4):  48%|████▊     | 48/100 [00:07<00:14,  3.70it/s]
# Rank steps (Trial 4):  49%|████▉     | 49/100 [00:07<00:14,  3.62it/s]
# Rank steps (Trial 4):  50%|█████     | 50/100 [00:07<00:15,  3.29it/s]
# Rank steps (Trial 4):  51%|█████     | 51/100 [00:08<00:18,  2.67it/s]
# Rank steps (Trial 4):  52%|█████▏    | 52/100 [00:08<00:20,  2.32it/s]
# Rank steps (Trial 4):  53%|█████▎    | 53/100 [00:09<00:24,  1.95it/s]
# Rank steps (Trial 4):  54%|█████▍    | 54/100 [00:10<00:24,  1.87it/s]
# Rank steps (Trial 4):  55%|█████▌    | 55/100 [00:10<00:24,  1.83it/s]
# Rank steps (Trial 4):  56%|█████▌    | 56/100 [00:11<00:24,  1.79it/s]
# Rank steps (Trial 4):  57%|█████▋    | 57/100 [00:11<00:24,  1.72it/s]
# Rank steps (Trial 4):  58%|█████▊    | 58/100 [00:12<00:21,  1.94it/s]
# Rank steps (Trial 4):  59%|█████▉    | 59/100 [00:12<00:18,  2.16it/s]
# Rank steps (Trial 4):  60%|██████    | 60/100 [00:12<00:17,  2.32it/s]
# Rank steps (Trial 4):  61%|██████    | 61/100 [00:13<00:16,  2.43it/s]
# Rank steps (Trial 4):  62%|██████▏   | 62/100 [00:13<00:15,  2.53it/s]
# Rank steps (Trial 4):  63%|██████▎   | 63/100 [00:14<00:14,  2.56it/s]
# Rank steps (Trial 4):  64%|██████▍   | 64/100 [00:14<00:13,  2.60it/s]
# Rank steps (Trial 4):  65%|██████▌   | 65/100 [00:14<00:13,  2.63it/s]
# Rank steps (Trial 4):  66%|██████▌   | 66/100 [00:15<00:13,  2.59it/s]
# Rank steps (Trial 4):  67%|██████▋   | 67/100 [00:15<00:12,  2.60it/s]
# Rank steps (Trial 4):  68%|██████▊   | 68/100 [00:15<00:12,  2.58it/s]
# Rank steps (Trial 4):  69%|██████▉   | 69/100 [00:16<00:12,  2.53it/s]
# Rank steps (Trial 4):  70%|███████   | 70/100 [00:16<00:11,  2.54it/s]
# Rank steps (Trial 4):  71%|███████   | 71/100 [00:17<00:11,  2.49it/s]
# Rank steps (Trial 4):  72%|███████▏  | 72/100 [00:17<00:11,  2.48it/s]
# Rank steps (Trial 4):  73%|███████▎  | 73/100 [00:18<00:10,  2.47it/s]
# Rank steps (Trial 4):  74%|███████▍  | 74/100 [00:18<00:10,  2.40it/s]
# Rank steps (Trial 4):  75%|███████▌  | 75/100 [00:18<00:10,  2.36it/s]
# Rank steps (Trial 4):  76%|███████▌  | 76/100 [00:19<00:10,  2.18it/s]
# Rank steps (Trial 4):  77%|███████▋  | 77/100 [00:19<00:10,  2.17it/s]
# Rank steps (Trial 4):  78%|███████▊  | 78/100 [00:20<00:10,  2.16it/s]
# Rank steps (Trial 4):  79%|███████▉  | 79/100 [00:20<00:09,  2.19it/s]
# Rank steps (Trial 4):  80%|████████  | 80/100 [00:21<00:09,  2.19it/s]
# Rank steps (Trial 4):  81%|████████  | 81/100 [00:21<00:08,  2.16it/s]
# Rank steps (Trial 4):  82%|████████▏ | 82/100 [00:22<00:09,  1.86it/s]
# Rank steps (Trial 4):  83%|████████▎ | 83/100 [00:23<00:10,  1.58it/s]
# Rank steps (Trial 4):  84%|████████▍ | 84/100 [00:24<00:11,  1.40it/s]
# Rank steps (Trial 4):  85%|████████▌ | 85/100 [00:25<00:11,  1.30it/s]
# Rank steps (Trial 4):  86%|████████▌ | 86/100 [00:26<00:11,  1.23it/s]
# Rank steps (Trial 4):  87%|████████▋ | 87/100 [00:26<00:09,  1.35it/s]
# Rank steps (Trial 4):  88%|████████▊ | 88/100 [00:27<00:08,  1.48it/s]
# Rank steps (Trial 4):  89%|████████▉ | 89/100 [00:27<00:06,  1.60it/s]
# Rank steps (Trial 4):  90%|█████████ | 90/100 [00:28<00:05,  1.68it/s]
# Rank steps (Trial 4):  91%|█████████ | 91/100 [00:28<00:05,  1.75it/s]
# Rank steps (Trial 4):  92%|█████████▏| 92/100 [00:29<00:04,  1.76it/s]
# Rank steps (Trial 4):  93%|█████████▎| 93/100 [00:29<00:04,  1.70it/s]
# Rank steps (Trial 4):  94%|█████████▍| 94/100 [00:30<00:03,  1.74it/s]
# Rank steps (Trial 4):  95%|█████████▌| 95/100 [00:30<00:02,  1.75it/s]
# Rank steps (Trial 4):  96%|█████████▌| 96/100 [00:31<00:02,  1.78it/s]
# Rank steps (Trial 4):  97%|█████████▋| 97/100 [00:32<00:01,  1.77it/s]
# Rank steps (Trial 4):  98%|█████████▊| 98/100 [00:32<00:01,  1.77it/s]
# Rank steps (Trial 4):  99%|█████████▉| 99/100 [00:33<00:00,  1.76it/s]
# Rank steps (Trial 4): 100%|██████████| 100/100 [00:33<00:00,  1.77it/s]
# Trials:  40%|████      | 4/10 [02:18<03:27, 34.52s/it]
# Rank steps (Trial 5):   0%|          | 0/100 [00:00<?, ?it/s]
# Rank steps (Trial 5):   5%|▌         | 5/100 [00:00<00:01, 49.89it/s]
# Rank steps (Trial 5):  10%|█         | 10/100 [00:00<00:03, 26.40it/s]
# Rank steps (Trial 5):  14%|█▍        | 14/100 [00:00<00:04, 19.53it/s]
# Rank steps (Trial 5):  17%|█▋        | 17/100 [00:00<00:05, 15.64it/s]
# Rank steps (Trial 5):  19%|█▉        | 19/100 [00:01<00:05, 13.57it/s]
# Rank steps (Trial 5):  21%|██        | 21/100 [00:01<00:06, 11.46it/s]
# Rank steps (Trial 5):  23%|██▎       | 23/100 [00:01<00:07,  9.99it/s]
# Rank steps (Trial 5):  25%|██▌       | 25/100 [00:01<00:08,  8.74it/s]
# Rank steps (Trial 5):  26%|██▌       | 26/100 [00:02<00:08,  8.28it/s]
# Rank steps (Trial 5):  27%|██▋       | 27/100 [00:02<00:09,  7.61it/s]
# Rank steps (Trial 5):  28%|██▊       | 28/100 [00:02<00:11,  6.43it/s]
# Rank steps (Trial 5):  29%|██▉       | 29/100 [00:02<00:13,  5.22it/s]
# Rank steps (Trial 5):  30%|███       | 30/100 [00:03<00:15,  4.48it/s]
# Rank steps (Trial 5):  31%|███       | 31/100 [00:03<00:17,  3.97it/s]
# Rank steps (Trial 5):  32%|███▏      | 32/100 [00:03<00:18,  3.69it/s]
# Rank steps (Trial 5):  33%|███▎      | 33/100 [00:04<00:19,  3.37it/s]
# Rank steps (Trial 5):  34%|███▍      | 34/100 [00:04<00:20,  3.17it/s]
# Rank steps (Trial 5):  35%|███▌      | 35/100 [00:04<00:21,  2.98it/s]
# Rank steps (Trial 5):  36%|███▌      | 36/100 [00:05<00:22,  2.80it/s]
# Rank steps (Trial 5):  37%|███▋      | 37/100 [00:05<00:24,  2.55it/s]
# Rank steps (Trial 5):  38%|███▊      | 38/100 [00:06<00:25,  2.45it/s]
# Rank steps (Trial 5):  39%|███▉      | 39/100 [00:06<00:25,  2.42it/s]
# Rank steps (Trial 5):  40%|████      | 40/100 [00:07<00:23,  2.61it/s]
# Rank steps (Trial 5):  41%|████      | 41/100 [00:07<00:20,  2.94it/s]
# Rank steps (Trial 5):  42%|████▏     | 42/100 [00:07<00:18,  3.21it/s]
# Rank steps (Trial 5):  43%|████▎     | 43/100 [00:07<00:16,  3.36it/s]
# Rank steps (Trial 5):  44%|████▍     | 44/100 [00:08<00:15,  3.50it/s]
# Rank steps (Trial 5):  45%|████▌     | 45/100 [00:08<00:15,  3.59it/s]
# Rank steps (Trial 5):  46%|████▌     | 46/100 [00:08<00:14,  3.64it/s]
# Rank steps (Trial 5):  47%|████▋     | 47/100 [00:08<00:14,  3.59it/s]
# Rank steps (Trial 5):  48%|████▊     | 48/100 [00:09<00:14,  3.60it/s]
# Rank steps (Trial 5):  49%|████▉     | 49/100 [00:09<00:14,  3.60it/s]
# Rank steps (Trial 5):  50%|█████     | 50/100 [00:09<00:14,  3.55it/s]
# Rank steps (Trial 5):  51%|█████     | 51/100 [00:09<00:14,  3.43it/s]
# Rank steps (Trial 5):  52%|█████▏    | 52/100 [00:10<00:14,  3.40it/s]
# Rank steps (Trial 5):  53%|█████▎    | 53/100 [00:10<00:13,  3.38it/s]
# Rank steps (Trial 5):  54%|█████▍    | 54/100 [00:10<00:14,  3.24it/s]
# Rank steps (Trial 5):  55%|█████▌    | 55/100 [00:11<00:13,  3.23it/s]
# Rank steps (Trial 5):  56%|█████▌    | 56/100 [00:11<00:13,  3.18it/s]
# Rank steps (Trial 5):  57%|█████▋    | 57/100 [00:11<00:13,  3.08it/s]
# Rank steps (Trial 5):  58%|█████▊    | 58/100 [00:12<00:13,  3.05it/s]
# Rank steps (Trial 5):  59%|█████▉    | 59/100 [00:12<00:13,  3.01it/s]
# Rank steps (Trial 5):  60%|██████    | 60/100 [00:12<00:13,  2.93it/s]
# Rank steps (Trial 5):  61%|██████    | 61/100 [00:13<00:13,  2.91it/s]
# Rank steps (Trial 5):  62%|██████▏   | 62/100 [00:13<00:13,  2.89it/s]
# Rank steps (Trial 5):  63%|██████▎   | 63/100 [00:14<00:13,  2.78it/s]
# Rank steps (Trial 5):  64%|██████▍   | 64/100 [00:14<00:13,  2.77it/s]
# Rank steps (Trial 5):  65%|██████▌   | 65/100 [00:14<00:12,  2.74it/s]
# Rank steps (Trial 5):  66%|██████▌   | 66/100 [00:15<00:12,  2.69it/s]
# Rank steps (Trial 5):  67%|██████▋   | 67/100 [00:15<00:12,  2.65it/s]
# Rank steps (Trial 5):  68%|██████▊   | 68/100 [00:16<00:13,  2.42it/s]
# Rank steps (Trial 5):  69%|██████▉   | 69/100 [00:16<00:12,  2.41it/s]
# Rank steps (Trial 5):  70%|███████   | 70/100 [00:16<00:12,  2.42it/s]
# Rank steps (Trial 5):  71%|███████   | 71/100 [00:17<00:14,  1.94it/s]
# Rank steps (Trial 5):  72%|███████▏  | 72/100 [00:18<00:16,  1.70it/s]
# Rank steps (Trial 5):  73%|███████▎  | 73/100 [00:19<00:17,  1.55it/s]
# Rank steps (Trial 5):  74%|███████▍  | 74/100 [00:19<00:17,  1.46it/s]
# Rank steps (Trial 5):  75%|███████▌  | 75/100 [00:20<00:17,  1.39it/s]
# Rank steps (Trial 5):  76%|███████▌  | 76/100 [00:21<00:16,  1.47it/s]
# Rank steps (Trial 5):  77%|███████▋  | 77/100 [00:21<00:14,  1.62it/s]
# Rank steps (Trial 5):  78%|███████▊  | 78/100 [00:22<00:12,  1.77it/s]
# Rank steps (Trial 5):  79%|███████▉  | 79/100 [00:22<00:11,  1.87it/s]
# Rank steps (Trial 5):  80%|████████  | 80/100 [00:23<00:10,  1.96it/s]
# Rank steps (Trial 5):  81%|████████  | 81/100 [00:23<00:09,  1.99it/s]
# Rank steps (Trial 5):  82%|████████▏ | 82/100 [00:24<00:08,  2.02it/s]
# Rank steps (Trial 5):  83%|████████▎ | 83/100 [00:24<00:08,  2.03it/s]
# Rank steps (Trial 5):  84%|████████▍ | 84/100 [00:25<00:07,  2.04it/s]
# Rank steps (Trial 5):  85%|████████▌ | 85/100 [00:25<00:07,  2.02it/s]
# Rank steps (Trial 5):  86%|████████▌ | 86/100 [00:26<00:07,  1.95it/s]
# Rank steps (Trial 5):  87%|████████▋ | 87/100 [00:26<00:06,  1.89it/s]
# Rank steps (Trial 5):  88%|████████▊ | 88/100 [00:27<00:06,  1.92it/s]
# Rank steps (Trial 5):  89%|████████▉ | 89/100 [00:27<00:05,  1.92it/s]
# Rank steps (Trial 5):  90%|█████████ | 90/100 [00:28<00:05,  1.93it/s]
# Rank steps (Trial 5):  91%|█████████ | 91/100 [00:28<00:04,  1.90it/s]
# Rank steps (Trial 5):  92%|█████████▏| 92/100 [00:29<00:04,  1.91it/s]
# Rank steps (Trial 5):  93%|█████████▎| 93/100 [00:29<00:03,  1.88it/s]
# Rank steps (Trial 5):  94%|█████████▍| 94/100 [00:30<00:03,  1.89it/s]
# Rank steps (Trial 5):  95%|█████████▌| 95/100 [00:30<00:02,  1.85it/s]
# Rank steps (Trial 5):  96%|█████████▌| 96/100 [00:31<00:02,  1.50it/s]
# Rank steps (Trial 5):  97%|█████████▋| 97/100 [00:32<00:02,  1.29it/s]
# Rank steps (Trial 5):  98%|█████████▊| 98/100 [00:34<00:01,  1.17it/s]
# Rank steps (Trial 5):  99%|█████████▉| 99/100 [00:35<00:00,  1.10it/s]
# Rank steps (Trial 5): 100%|██████████| 100/100 [00:35<00:00,  1.17it/s]
# Trials:  50%|█████     | 5/10 [02:54<02:54, 34.97s/it]
# Rank steps (Trial 6):   0%|          | 0/100 [00:00<?, ?it/s]
# Rank steps (Trial 6):   5%|▌         | 5/100 [00:00<00:02, 47.44it/s]
# Rank steps (Trial 6):  10%|█         | 10/100 [00:00<00:03, 26.80it/s]
# Rank steps (Trial 6):  14%|█▍        | 14/100 [00:00<00:04, 18.79it/s]
# Rank steps (Trial 6):  17%|█▋        | 17/100 [00:00<00:05, 14.56it/s]
# Rank steps (Trial 6):  19%|█▉        | 19/100 [00:01<00:06, 12.02it/s]
# Rank steps (Trial 6):  21%|██        | 21/100 [00:01<00:07, 10.33it/s]
# Rank steps (Trial 6):  23%|██▎       | 23/100 [00:01<00:08,  9.42it/s]
# Rank steps (Trial 6):  25%|██▌       | 25/100 [00:02<00:08,  8.64it/s]
# Rank steps (Trial 6):  26%|██▌       | 26/100 [00:02<00:09,  8.12it/s]
# Rank steps (Trial 6):  27%|██▋       | 27/100 [00:02<00:09,  7.72it/s]
# Rank steps (Trial 6):  28%|██▊       | 28/100 [00:02<00:10,  7.09it/s]
# Rank steps (Trial 6):  29%|██▉       | 29/100 [00:02<00:10,  6.78it/s]
# Rank steps (Trial 6):  30%|███       | 30/100 [00:02<00:10,  6.44it/s]
# Rank steps (Trial 6):  31%|███       | 31/100 [00:03<00:11,  6.12it/s]
# Rank steps (Trial 6):  32%|███▏      | 32/100 [00:03<00:11,  5.85it/s]
# Rank steps (Trial 6):  33%|███▎      | 33/100 [00:03<00:11,  5.66it/s]
# Rank steps (Trial 6):  34%|███▍      | 34/100 [00:03<00:12,  5.30it/s]
# Rank steps (Trial 6):  35%|███▌      | 35/100 [00:03<00:12,  5.16it/s]
# Rank steps (Trial 6):  36%|███▌      | 36/100 [00:04<00:12,  5.03it/s]
# Rank steps (Trial 6):  37%|███▋      | 37/100 [00:04<00:12,  4.87it/s]
# Rank steps (Trial 6):  38%|███▊      | 38/100 [00:04<00:13,  4.75it/s]
# Rank steps (Trial 6):  39%|███▉      | 39/100 [00:04<00:13,  4.54it/s]
# Rank steps (Trial 6):  40%|████      | 40/100 [00:05<00:13,  4.49it/s]
# Rank steps (Trial 6):  41%|████      | 41/100 [00:05<00:13,  4.34it/s]
# Rank steps (Trial 6):  42%|████▏     | 42/100 [00:05<00:13,  4.24it/s]
# Rank steps (Trial 6):  43%|████▎     | 43/100 [00:05<00:14,  4.06it/s]
# Rank steps (Trial 6):  44%|████▍     | 44/100 [00:06<00:13,  4.03it/s]
# Rank steps (Trial 6):  45%|████▌     | 45/100 [00:06<00:13,  3.96it/s]
# Rank steps (Trial 6):  46%|████▌     | 46/100 [00:06<00:13,  3.89it/s]
# Rank steps (Trial 6):  47%|████▋     | 47/100 [00:06<00:14,  3.76it/s]
# Rank steps (Trial 6):  48%|████▊     | 48/100 [00:07<00:13,  3.73it/s]
# Rank steps (Trial 6):  49%|████▉     | 49/100 [00:07<00:13,  3.67it/s]
# Rank steps (Trial 6):  50%|█████     | 50/100 [00:07<00:14,  3.54it/s]
# Rank steps (Trial 6):  51%|█████     | 51/100 [00:08<00:14,  3.50it/s]
# Rank steps (Trial 6):  52%|█████▏    | 52/100 [00:08<00:14,  3.42it/s]
# Rank steps (Trial 6):  53%|█████▎    | 53/100 [00:08<00:13,  3.38it/s]
# Rank steps (Trial 6):  54%|█████▍    | 54/100 [00:08<00:14,  3.26it/s]
# Rank steps (Trial 6):  55%|█████▌    | 55/100 [00:09<00:13,  3.22it/s]
# Rank steps (Trial 6):  56%|█████▌    | 56/100 [00:09<00:13,  3.18it/s]
# Rank steps (Trial 6):  57%|█████▋    | 57/100 [00:10<00:17,  2.46it/s]
# Rank steps (Trial 6):  58%|█████▊    | 58/100 [00:10<00:19,  2.13it/s]
# Rank steps (Trial 6):  59%|█████▉    | 59/100 [00:11<00:21,  1.89it/s]
# Rank steps (Trial 6):  60%|██████    | 60/100 [00:12<00:22,  1.76it/s]
# Rank steps (Trial 6):  61%|██████    | 61/100 [00:12<00:23,  1.69it/s]
# Rank steps (Trial 6):  62%|██████▏   | 62/100 [00:13<00:23,  1.64it/s]
# Rank steps (Trial 6):  63%|██████▎   | 63/100 [00:14<00:22,  1.61it/s]
# Rank steps (Trial 6):  64%|██████▍   | 64/100 [00:14<00:19,  1.83it/s]
# Rank steps (Trial 6):  65%|██████▌   | 65/100 [00:14<00:17,  2.03it/s]
# Rank steps (Trial 6):  66%|██████▌   | 66/100 [00:15<00:15,  2.16it/s]
# Rank steps (Trial 6):  67%|██████▋   | 67/100 [00:15<00:14,  2.28it/s]
# Rank steps (Trial 6):  68%|██████▊   | 68/100 [00:16<00:13,  2.35it/s]
# Rank steps (Trial 6):  69%|██████▉   | 69/100 [00:16<00:13,  2.37it/s]
# Rank steps (Trial 6):  70%|███████   | 70/100 [00:16<00:12,  2.41it/s]
# Rank steps (Trial 6):  71%|███████   | 71/100 [00:17<00:11,  2.42it/s]
# Rank steps (Trial 6):  72%|███████▏  | 72/100 [00:17<00:11,  2.41it/s]
# Rank steps (Trial 6):  73%|███████▎  | 73/100 [00:18<00:11,  2.40it/s]
# Rank steps (Trial 6):  74%|███████▍  | 74/100 [00:18<00:10,  2.37it/s]
# Rank steps (Trial 6):  75%|███████▌  | 75/100 [00:18<00:10,  2.36it/s]
# Rank steps (Trial 6):  76%|███████▌  | 76/100 [00:19<00:10,  2.32it/s]
# Rank steps (Trial 6):  77%|███████▋  | 77/100 [00:19<00:09,  2.32it/s]
# Rank steps (Trial 6):  78%|███████▊  | 78/100 [00:20<00:09,  2.30it/s]
# Rank steps (Trial 6):  79%|███████▉  | 79/100 [00:20<00:09,  2.24it/s]
# Rank steps (Trial 6):  80%|████████  | 80/100 [00:21<00:09,  2.21it/s]
# Rank steps (Trial 6):  81%|████████  | 81/100 [00:21<00:09,  2.02it/s]
# Rank steps (Trial 6):  82%|████████▏ | 82/100 [00:22<00:08,  2.06it/s]
# Rank steps (Trial 6):  83%|████████▎ | 83/100 [00:22<00:08,  2.04it/s]
# Rank steps (Trial 6):  84%|████████▍ | 84/100 [00:23<00:07,  2.06it/s]
# Rank steps (Trial 6):  85%|████████▌ | 85/100 [00:23<00:07,  2.04it/s]
# Rank steps (Trial 6):  86%|████████▌ | 86/100 [00:24<00:07,  1.87it/s]
# Rank steps (Trial 6):  87%|████████▋ | 87/100 [00:25<00:08,  1.52it/s]
# Rank steps (Trial 6):  88%|████████▊ | 88/100 [00:26<00:08,  1.35it/s]
# Rank steps (Trial 6):  89%|████████▉ | 89/100 [00:27<00:08,  1.26it/s]
# Rank steps (Trial 6):  90%|█████████ | 90/100 [00:28<00:08,  1.19it/s]
# Rank steps (Trial 6):  91%|█████████ | 91/100 [00:28<00:06,  1.29it/s]
# Rank steps (Trial 6):  92%|█████████▏| 92/100 [00:29<00:05,  1.42it/s]
# Rank steps (Trial 6):  93%|█████████▎| 93/100 [00:29<00:04,  1.53it/s]
# Rank steps (Trial 6):  94%|█████████▍| 94/100 [00:30<00:03,  1.61it/s]
# Rank steps (Trial 6):  95%|█████████▌| 95/100 [00:30<00:02,  1.67it/s]
# Rank steps (Trial 6):  96%|█████████▌| 96/100 [00:31<00:02,  1.68it/s]
# Rank steps (Trial 6):  97%|█████████▋| 97/100 [00:32<00:01,  1.62it/s]
# Rank steps (Trial 6):  98%|█████████▊| 98/100 [00:32<00:01,  1.67it/s]
# Rank steps (Trial 6):  99%|█████████▉| 99/100 [00:33<00:00,  1.69it/s]
# Rank steps (Trial 6): 100%|██████████| 100/100 [00:33<00:00,  1.71it/s]
# Trials:  60%|██████    | 6/10 [03:28<02:18, 34.61s/it]
# Rank steps (Trial 7):   0%|          | 0/100 [00:00<?, ?it/s]
# Rank steps (Trial 7):   5%|▌         | 5/100 [00:00<00:02, 46.37it/s]
# Rank steps (Trial 7):  10%|█         | 10/100 [00:00<00:03, 25.64it/s]
# Rank steps (Trial 7):  14%|█▍        | 14/100 [00:00<00:04, 18.97it/s]
# Rank steps (Trial 7):  17%|█▋        | 17/100 [00:00<00:05, 15.46it/s]
# Rank steps (Trial 7):  19%|█▉        | 19/100 [00:01<00:06, 13.32it/s]
# Rank steps (Trial 7):  21%|██        | 21/100 [00:01<00:06, 11.33it/s]
# Rank steps (Trial 7):  23%|██▎       | 23/100 [00:01<00:07, 10.10it/s]
# Rank steps (Trial 7):  25%|██▌       | 25/100 [00:01<00:08,  9.01it/s]
# Rank steps (Trial 7):  26%|██▌       | 26/100 [00:02<00:08,  8.47it/s]
# Rank steps (Trial 7):  27%|██▋       | 27/100 [00:02<00:09,  7.91it/s]
# Rank steps (Trial 7):  28%|██▊       | 28/100 [00:02<00:10,  7.15it/s]
# Rank steps (Trial 7):  29%|██▉       | 29/100 [00:02<00:10,  6.71it/s]
# Rank steps (Trial 7):  30%|███       | 30/100 [00:02<00:10,  6.43it/s]
# Rank steps (Trial 7):  31%|███       | 31/100 [00:03<00:11,  6.10it/s]
# Rank steps (Trial 7):  32%|███▏      | 32/100 [00:03<00:11,  5.86it/s]
# Rank steps (Trial 7):  33%|███▎      | 33/100 [00:03<00:12,  5.45it/s]
# Rank steps (Trial 7):  34%|███▍      | 34/100 [00:03<00:12,  5.30it/s]
# Rank steps (Trial 7):  35%|███▌      | 35/100 [00:03<00:12,  5.15it/s]
# Rank steps (Trial 7):  36%|███▌      | 36/100 [00:04<00:12,  5.01it/s]
# Rank steps (Trial 7):  37%|███▋      | 37/100 [00:04<00:12,  4.87it/s]
# Rank steps (Trial 7):  38%|███▊      | 38/100 [00:04<00:13,  4.52it/s]
# Rank steps (Trial 7):  39%|███▉      | 39/100 [00:04<00:17,  3.58it/s]
# Rank steps (Trial 7):  40%|████      | 40/100 [00:05<00:19,  3.04it/s]
# Rank steps (Trial 7):  41%|████      | 41/100 [00:05<00:21,  2.78it/s]
# Rank steps (Trial 7):  42%|████▏     | 42/100 [00:06<00:22,  2.56it/s]
# Rank steps (Trial 7):  43%|████▎     | 43/100 [00:06<00:23,  2.42it/s]
# Rank steps (Trial 7):  44%|████▍     | 44/100 [00:07<00:24,  2.32it/s]
# Rank steps (Trial 7):  45%|████▌     | 45/100 [00:07<00:24,  2.26it/s]
# Rank steps (Trial 7):  46%|████▌     | 46/100 [00:08<00:25,  2.10it/s]
# Rank steps (Trial 7):  47%|████▋     | 47/100 [00:08<00:26,  1.98it/s]
# Rank steps (Trial 7):  48%|████▊     | 48/100 [00:09<00:23,  2.18it/s]
# Rank steps (Trial 7):  49%|████▉     | 49/100 [00:09<00:20,  2.47it/s]
# Rank steps (Trial 7):  50%|█████     | 50/100 [00:09<00:18,  2.69it/s]
# Rank steps (Trial 7):  51%|█████     | 51/100 [00:10<00:17,  2.81it/s]
# Rank steps (Trial 7):  52%|█████▏    | 52/100 [00:10<00:16,  2.95it/s]
# Rank steps (Trial 7):  53%|█████▎    | 53/100 [00:10<00:15,  3.03it/s]
# Rank steps (Trial 7):  54%|█████▍    | 54/100 [00:10<00:15,  3.04it/s]
# Rank steps (Trial 7):  55%|█████▌    | 55/100 [00:11<00:14,  3.07it/s]
# Rank steps (Trial 7):  56%|█████▌    | 56/100 [00:11<00:14,  3.08it/s]
# Rank steps (Trial 7):  57%|█████▋    | 57/100 [00:11<00:14,  3.01it/s]
# Rank steps (Trial 7):  58%|█████▊    | 58/100 [00:12<00:13,  3.00it/s]
# Rank steps (Trial 7):  59%|█████▉    | 59/100 [00:12<00:13,  2.96it/s]
# Rank steps (Trial 7):  60%|██████    | 60/100 [00:13<00:13,  2.88it/s]
# Rank steps (Trial 7):  61%|██████    | 61/100 [00:13<00:13,  2.88it/s]
# Rank steps (Trial 7):  62%|██████▏   | 62/100 [00:13<00:13,  2.86it/s]
# Rank steps (Trial 7):  63%|██████▎   | 63/100 [00:14<00:13,  2.79it/s]
# Rank steps (Trial 7):  64%|██████▍   | 64/100 [00:14<00:12,  2.79it/s]
# Rank steps (Trial 7):  65%|██████▌   | 65/100 [00:14<00:12,  2.74it/s]
# Rank steps (Trial 7):  66%|██████▌   | 66/100 [00:15<00:12,  2.67it/s]
# Rank steps (Trial 7):  67%|██████▋   | 67/100 [00:15<00:12,  2.64it/s]
# Rank steps (Trial 7):  68%|██████▊   | 68/100 [00:16<00:12,  2.59it/s]
# Rank steps (Trial 7):  69%|██████▉   | 69/100 [00:16<00:12,  2.56it/s]
# Rank steps (Trial 7):  70%|███████   | 70/100 [00:16<00:11,  2.53it/s]
# Rank steps (Trial 7):  71%|███████   | 71/100 [00:17<00:11,  2.47it/s]
# Rank steps (Trial 7):  72%|███████▏  | 72/100 [00:17<00:11,  2.47it/s]
# Rank steps (Trial 7):  73%|███████▎  | 73/100 [00:18<00:11,  2.43it/s]
# Rank steps (Trial 7):  74%|███████▍  | 74/100 [00:18<00:10,  2.37it/s]
# Rank steps (Trial 7):  75%|███████▌  | 75/100 [00:19<00:12,  2.05it/s]
# Rank steps (Trial 7):  76%|███████▌  | 76/100 [00:19<00:13,  1.72it/s]
# Rank steps (Trial 7):  77%|███████▋  | 77/100 [00:20<00:15,  1.53it/s]
# Rank steps (Trial 7):  78%|███████▊  | 78/100 [00:21<00:15,  1.40it/s]
# Rank steps (Trial 7):  79%|███████▉  | 79/100 [00:22<00:15,  1.32it/s]
# Rank steps (Trial 7):  80%|████████  | 80/100 [00:23<00:15,  1.30it/s]
# Rank steps (Trial 7):  81%|████████  | 81/100 [00:23<00:13,  1.46it/s]
# Rank steps (Trial 7):  82%|████████▏ | 82/100 [00:24<00:11,  1.61it/s]
# Rank steps (Trial 7):  83%|████████▎ | 83/100 [00:24<00:09,  1.71it/s]
# Rank steps (Trial 7):  84%|████████▍ | 84/100 [00:25<00:08,  1.80it/s]
# Rank steps (Trial 7):  85%|████████▌ | 85/100 [00:25<00:08,  1.85it/s]
# Rank steps (Trial 7):  86%|████████▌ | 86/100 [00:26<00:07,  1.90it/s]
# Rank steps (Trial 7):  87%|████████▋ | 87/100 [00:26<00:06,  1.92it/s]
# Rank steps (Trial 7):  88%|████████▊ | 88/100 [00:27<00:06,  1.94it/s]
# Rank steps (Trial 7):  89%|████████▉ | 89/100 [00:27<00:05,  1.93it/s]
# Rank steps (Trial 7):  90%|█████████ | 90/100 [00:28<00:05,  1.94it/s]
# Rank steps (Trial 7):  91%|█████████ | 91/100 [00:28<00:04,  1.93it/s]
# Rank steps (Trial 7):  92%|█████████▏| 92/100 [00:29<00:04,  1.92it/s]
# Rank steps (Trial 7):  93%|█████████▎| 93/100 [00:29<00:03,  1.88it/s]
# Rank steps (Trial 7):  94%|█████████▍| 94/100 [00:30<00:03,  1.88it/s]
# Rank steps (Trial 7):  95%|█████████▌| 95/100 [00:31<00:02,  1.85it/s]
# Rank steps (Trial 7):  96%|█████████▌| 96/100 [00:31<00:02,  1.84it/s]
# Rank steps (Trial 7):  97%|█████████▋| 97/100 [00:32<00:01,  1.81it/s]
# Rank steps (Trial 7):  98%|█████████▊| 98/100 [00:32<00:01,  1.80it/s]
# Rank steps (Trial 7):  99%|█████████▉| 99/100 [00:33<00:00,  1.74it/s]
# Rank steps (Trial 7): 100%|██████████| 100/100 [00:34<00:00,  1.39it/s]
# Trials:  70%|███████   | 7/10 [04:02<01:43, 34.55s/it]
# Rank steps (Trial 8):   0%|          | 0/100 [00:00<?, ?it/s]
# Rank steps (Trial 8):   4%|▍         | 4/100 [00:00<00:02, 39.17it/s]
# Rank steps (Trial 8):   8%|▊         | 8/100 [00:00<00:04, 19.44it/s]
# Rank steps (Trial 8):  11%|█         | 11/100 [00:00<00:06, 13.19it/s]
# Rank steps (Trial 8):  13%|█▎        | 13/100 [00:00<00:07, 10.90it/s]
# Rank steps (Trial 8):  15%|█▌        | 15/100 [00:01<00:09,  8.92it/s]
# Rank steps (Trial 8):  17%|█▋        | 17/100 [00:01<00:10,  7.62it/s]
# Rank steps (Trial 8):  18%|█▊        | 18/100 [00:01<00:11,  6.95it/s]
# Rank steps (Trial 8):  19%|█▉        | 19/100 [00:02<00:12,  6.47it/s]
# Rank steps (Trial 8):  20%|██        | 20/100 [00:02<00:13,  5.94it/s]
# Rank steps (Trial 8):  21%|██        | 21/100 [00:02<00:14,  5.44it/s]
# Rank steps (Trial 8):  22%|██▏       | 22/100 [00:02<00:15,  5.01it/s]
# Rank steps (Trial 8):  23%|██▎       | 23/100 [00:03<00:16,  4.68it/s]
# Rank steps (Trial 8):  24%|██▍       | 24/100 [00:03<00:16,  4.66it/s]
# Rank steps (Trial 8):  25%|██▌       | 25/100 [00:03<00:14,  5.08it/s]
# Rank steps (Trial 8):  26%|██▌       | 26/100 [00:03<00:13,  5.35it/s]
# Rank steps (Trial 8):  27%|██▋       | 27/100 [00:03<00:13,  5.54it/s]
# Rank steps (Trial 8):  28%|██▊       | 28/100 [00:03<00:12,  5.68it/s]
# Rank steps (Trial 8):  29%|██▉       | 29/100 [00:04<00:12,  5.55it/s]
# Rank steps (Trial 8):  30%|███       | 30/100 [00:04<00:12,  5.52it/s]
# Rank steps (Trial 8):  31%|███       | 31/100 [00:04<00:12,  5.47it/s]
# Rank steps (Trial 8):  32%|███▏      | 32/100 [00:04<00:12,  5.30it/s]
# Rank steps (Trial 8):  33%|███▎      | 33/100 [00:04<00:12,  5.24it/s]
# Rank steps (Trial 8):  34%|███▍      | 34/100 [00:05<00:13,  5.01it/s]
# Rank steps (Trial 8):  35%|███▌      | 35/100 [00:05<00:13,  4.99it/s]
# Rank steps (Trial 8):  36%|███▌      | 36/100 [00:05<00:13,  4.82it/s]
# Rank steps (Trial 8):  37%|███▋      | 37/100 [00:05<00:13,  4.72it/s]
# Rank steps (Trial 8):  38%|███▊      | 38/100 [00:05<00:13,  4.67it/s]
# Rank steps (Trial 8):  39%|███▉      | 39/100 [00:06<00:13,  4.47it/s]
# Rank steps (Trial 8):  40%|████      | 40/100 [00:06<00:13,  4.39it/s]
# Rank steps (Trial 8):  41%|████      | 41/100 [00:06<00:13,  4.29it/s]
# Rank steps (Trial 8):  42%|████▏     | 42/100 [00:06<00:13,  4.21it/s]
# Rank steps (Trial 8):  43%|████▎     | 43/100 [00:07<00:14,  4.06it/s]
# Rank steps (Trial 8):  44%|████▍     | 44/100 [00:07<00:13,  4.02it/s]
# Rank steps (Trial 8):  45%|████▌     | 45/100 [00:07<00:14,  3.92it/s]
# Rank steps (Trial 8):  46%|████▌     | 46/100 [00:07<00:14,  3.84it/s]
# Rank steps (Trial 8):  47%|████▋     | 47/100 [00:08<00:14,  3.71it/s]
# Rank steps (Trial 8):  48%|████▊     | 48/100 [00:08<00:14,  3.64it/s]
# Rank steps (Trial 8):  49%|████▉     | 49/100 [00:08<00:14,  3.59it/s]
# Rank steps (Trial 8):  50%|█████     | 50/100 [00:09<00:14,  3.55it/s]
# Rank steps (Trial 8):  51%|█████     | 51/100 [00:09<00:14,  3.41it/s]
# Rank steps (Trial 8):  52%|█████▏    | 52/100 [00:09<00:14,  3.35it/s]
# Rank steps (Trial 8):  53%|█████▎    | 53/100 [00:10<00:14,  3.32it/s]
# Rank steps (Trial 8):  54%|█████▍    | 54/100 [00:10<00:14,  3.22it/s]
# Rank steps (Trial 8):  55%|█████▌    | 55/100 [00:10<00:14,  3.18it/s]
# Rank steps (Trial 8):  56%|█████▌    | 56/100 [00:11<00:13,  3.15it/s]
# Rank steps (Trial 8):  57%|█████▋    | 57/100 [00:11<00:14,  3.05it/s]
# Rank steps (Trial 8):  58%|█████▊    | 58/100 [00:11<00:13,  3.02it/s]
# Rank steps (Trial 8):  59%|█████▉    | 59/100 [00:12<00:13,  3.01it/s]
# Rank steps (Trial 8):  60%|██████    | 60/100 [00:12<00:13,  2.92it/s]
# Rank steps (Trial 8):  61%|██████    | 61/100 [00:12<00:13,  2.91it/s]
# Rank steps (Trial 8):  62%|██████▏   | 62/100 [00:13<00:13,  2.87it/s]
# Rank steps (Trial 8):  63%|██████▎   | 63/100 [00:13<00:16,  2.27it/s]
# Rank steps (Trial 8):  64%|██████▍   | 64/100 [00:14<00:18,  1.97it/s]
# Rank steps (Trial 8):  65%|██████▌   | 65/100 [00:15<00:19,  1.79it/s]
# Rank steps (Trial 8):  66%|██████▌   | 66/100 [00:15<00:20,  1.64it/s]
# Rank steps (Trial 8):  67%|██████▋   | 67/100 [00:16<00:20,  1.57it/s]
# Rank steps (Trial 8):  68%|██████▊   | 68/100 [00:17<00:21,  1.50it/s]
# Rank steps (Trial 8):  69%|██████▉   | 69/100 [00:17<00:18,  1.66it/s]
# Rank steps (Trial 8):  70%|███████   | 70/100 [00:18<00:16,  1.82it/s]
# Rank steps (Trial 8):  71%|███████   | 71/100 [00:18<00:14,  1.97it/s]
# Rank steps (Trial 8):  72%|███████▏  | 72/100 [00:19<00:13,  2.06it/s]
# Rank steps (Trial 8):  73%|███████▎  | 73/100 [00:19<00:12,  2.15it/s]
# Rank steps (Trial 8):  74%|███████▍  | 74/100 [00:19<00:11,  2.18it/s]
# Rank steps (Trial 8):  75%|███████▌  | 75/100 [00:20<00:11,  2.22it/s]
# Rank steps (Trial 8):  76%|███████▌  | 76/100 [00:20<00:10,  2.23it/s]
# ...
# Rank steps (Trial 8):  61%|██████    | 61/100 [00:13<00:13,  2.85it/s]
# Rank steps (Trial 8):  62%|██████▏   | 62/100 [00:13<00:13,  2.82it/s]
# Rank steps (Trial 8):  63%|██████▎   | 63/100 [00:14<00:13,  2.79it/s]
# Rank steps (Trial 8):  64%|██████▍   | 64/100 [00:14<00:13,  2.71it/s]
# Rank steps (Trial 8):  65%|██████▌   | 65/100 [00:14<00:13,  2.69it/s]
# Rank steps (Trial 8):  66%|██████▌   | 66/100 [00:15<00:12,  2.63it/s]
# Rank steps (Trial 8):  67%|██████▋   | 67/100 [00:15<00:12,  2.60it/s]
# Rank steps (Trial 8):  68%|██████▊   | 68/100 [00:16<00:12,  2.58it/s]
# Rank steps (Trial 8):  69%|██████▉   | 69/100 [00:16<00:12,  2.53it/s]
# Rank steps (Trial 8):  70%|███████   | 70/100 [00:16<00:11,  2.51it/s]
# Rank steps (Trial 8):  71%|███████   | 71/100 [00:17<00:11,  2.47it/s]
# Rank steps (Trial 8):  72%|███████▏  | 72/100 [00:17<00:11,  2.41it/s]
# Rank steps (Trial 8):  73%|███████▎  | 73/100 [00:18<00:11,  2.38it/s]
# Rank steps (Trial 8):  74%|███████▍  | 74/100 [00:18<00:12,  2.03it/s]
# Rank steps (Trial 8):  75%|███████▌  | 75/100 [00:19<00:14,  1.71it/s]
# Rank steps (Trial 8):  76%|███████▌  | 76/100 [00:20<00:15,  1.54it/s]
# Rank steps (Trial 8):  77%|███████▋  | 77/100 [00:21<00:15,  1.44it/s]
# Rank steps (Trial 8):  78%|███████▊  | 78/100 [00:22<00:16,  1.35it/s]
# Rank steps (Trial 8):  79%|███████▉  | 79/100 [00:22<00:15,  1.37it/s]
# Rank steps (Trial 8):  80%|████████  | 80/100 [00:23<00:12,  1.55it/s]
# Rank steps (Trial 8):  81%|████████  | 81/100 [00:23<00:11,  1.69it/s]
# Rank steps (Trial 8):  82%|████████▏ | 82/100 [00:24<00:10,  1.78it/s]
# Rank steps (Trial 8):  83%|████████▎ | 83/100 [00:24<00:09,  1.87it/s]
# Rank steps (Trial 8):  84%|████████▍ | 84/100 [00:25<00:08,  1.90it/s]
# Rank steps (Trial 8):  85%|████████▌ | 85/100 [00:25<00:07,  1.95it/s]
# Rank steps (Trial 8):  86%|████████▌ | 86/100 [00:26<00:07,  1.95it/s]
# Rank steps (Trial 8):  87%|████████▋ | 87/100 [00:26<00:06,  1.97it/s]
# Rank steps (Trial 8):  88%|████████▊ | 88/100 [00:27<00:06,  1.95it/s]
# Rank steps (Trial 8):  89%|████████▉ | 89/100 [00:27<00:05,  1.95it/s]
# Rank steps (Trial 8):  90%|█████████ | 90/100 [00:28<00:05,  1.90it/s]
# Rank steps (Trial 8):  91%|█████████ | 91/100 [00:28<00:04,  1.92it/s]
# Rank steps (Trial 8):  92%|█████████▏| 92/100 [00:29<00:04,  1.84it/s]
# Rank steps (Trial 8):  93%|█████████▎| 93/100 [00:29<00:03,  1.86it/s]
# Rank steps (Trial 8):  94%|█████████▍| 94/100 [00:30<00:03,  1.84it/s]
# Rank steps (Trial 8):  95%|█████████▌| 95/100 [00:30<00:02,  1.85it/s]
# Rank steps (Trial 8):  96%|█████████▌| 96/100 [00:31<00:02,  1.82it/s]
# Rank steps (Trial 8):  97%|█████████▋| 97/100 [00:32<00:01,  1.82it/s]
# Rank steps (Trial 8):  98%|█████████▊| 98/100 [00:32<00:01,  1.66it/s]
# Rank steps (Trial 8):  99%|█████████▉| 99/100 [00:33<00:00,  1.36it/s]
# Rank steps (Trial 8): 100%|██████████| 100/100 [00:34<00:00,  1.19it/s]
# Trials:  80%|████████  | 8/10 [04:40<01:10, 35.19s/it]
# Rank steps (Trial 9):   0%|          | 0/100 [00:00<?, ?it/s]
# Rank steps (Trial 9):   4%|▍         | 4/100 [00:00<00:03, 26.45it/s]
# Rank steps (Trial 9):   7%|▋         | 7/100 [00:00<00:04, 19.70it/s]
# Rank steps (Trial 9):  10%|█         | 10/100 [00:00<00:06, 14.33it/s]
# Rank steps (Trial 9):  12%|█▏        | 12/100 [00:00<00:07, 11.93it/s]
# Rank steps (Trial 9):  14%|█▍        | 14/100 [00:01<00:08,  9.64it/s]
# Rank steps (Trial 9):  16%|█▌        | 16/100 [00:01<00:10,  8.25it/s]
# Rank steps (Trial 9):  17%|█▋        | 17/100 [00:01<00:11,  7.43it/s]
# Rank steps (Trial 9):  18%|█▊        | 18/100 [00:01<00:11,  6.92it/s]
# Rank steps (Trial 9):  19%|█▉        | 19/100 [00:01<00:11,  7.18it/s]
# Rank steps (Trial 9):  20%|██        | 20/100 [00:02<00:10,  7.33it/s]
# Rank steps (Trial 9):  21%|██        | 21/100 [00:02<00:10,  7.35it/s]
# Rank steps (Trial 9):  22%|██▏       | 22/100 [00:02<00:10,  7.34it/s]
# Rank steps (Trial 9):  23%|██▎       | 23/100 [00:02<00:10,  7.20it/s]
# Rank steps (Trial 9):  24%|██▍       | 24/100 [00:02<00:11,  6.79it/s]
# Rank steps (Trial 9):  25%|██▌       | 25/100 [00:02<00:11,  6.66it/s]
# Rank steps (Trial 9):  26%|██▌       | 26/100 [00:03<00:11,  6.52it/s]
# Rank steps (Trial 9):  27%|██▋       | 27/100 [00:03<00:11,  6.36it/s]
# Rank steps (Trial 9):  28%|██▊       | 28/100 [00:03<00:11,  6.20it/s]
# Rank steps (Trial 9):  29%|██▉       | 29/100 [00:03<00:11,  5.98it/s]
# Rank steps (Trial 9):  30%|███       | 30/100 [00:03<00:12,  5.62it/s]
# Rank steps (Trial 9):  31%|███       | 31/100 [00:03<00:12,  5.47it/s]
# Rank steps (Trial 9):  32%|███▏      | 32/100 [00:04<00:12,  5.36it/s]
# Rank steps (Trial 9):  33%|███▎      | 33/100 [00:04<00:12,  5.18it/s]
# Rank steps (Trial 9):  34%|███▍      | 34/100 [00:04<00:13,  5.03it/s]
# Rank steps (Trial 9):  35%|███▌      | 35/100 [00:04<00:13,  4.78it/s]
# Rank steps (Trial 9):  36%|███▌      | 36/100 [00:05<00:13,  4.74it/s]
# Rank steps (Trial 9):  37%|███▋      | 37/100 [00:05<00:13,  4.63it/s]
# Rank steps (Trial 9):  38%|███▊      | 38/100 [00:05<00:13,  4.56it/s]
# Rank steps (Trial 9):  39%|███▉      | 39/100 [00:05<00:13,  4.40it/s]
# Rank steps (Trial 9):  40%|████      | 40/100 [00:05<00:14,  4.27it/s]
# Rank steps (Trial 9):  41%|████      | 41/100 [00:06<00:13,  4.22it/s]
# Rank steps (Trial 9):  42%|████▏     | 42/100 [00:06<00:14,  4.11it/s]
# Rank steps (Trial 9):  43%|████▎     | 43/100 [00:06<00:14,  4.06it/s]
# Rank steps (Trial 9):  44%|████▍     | 44/100 [00:06<00:14,  3.90it/s]
# Rank steps (Trial 9):  45%|████▌     | 45/100 [00:07<00:14,  3.87it/s]
# Rank steps (Trial 9):  46%|████▌     | 46/100 [00:07<00:14,  3.75it/s]
# Rank steps (Trial 9):  47%|████▋     | 47/100 [00:07<00:14,  3.62it/s]
# Rank steps (Trial 9):  48%|████▊     | 48/100 [00:08<00:14,  3.60it/s]
# Rank steps (Trial 9):  49%|████▉     | 49/100 [00:08<00:14,  3.55it/s]
# Rank steps (Trial 9):  50%|█████     | 50/100 [00:08<00:14,  3.50it/s]
# Rank steps (Trial 9):  51%|█████     | 51/100 [00:09<00:14,  3.40it/s]
# Rank steps (Trial 9):  52%|█████▏    | 52/100 [00:09<00:14,  3.38it/s]
# Rank steps (Trial 9):  53%|█████▎    | 53/100 [00:09<00:14,  3.33it/s]
# Rank steps (Trial 9):  54%|█████▍    | 54/100 [00:09<00:14,  3.21it/s]
# Rank steps (Trial 9):  55%|█████▌    | 55/100 [00:10<00:14,  3.19it/s]
# Rank steps (Trial 9):  56%|█████▌    | 56/100 [00:10<00:13,  3.16it/s]
# Rank steps (Trial 9):  57%|█████▋    | 57/100 [00:10<00:14,  3.06it/s]
# Rank steps (Trial 9):  58%|█████▊    | 58/100 [00:11<00:13,  3.04it/s]
# Rank steps (Trial 9):  59%|█████▉    | 59/100 [00:11<00:13,  2.99it/s]
# Rank steps (Trial 9):  60%|██████    | 60/100 [00:12<00:15,  2.61it/s]
# Rank steps (Trial 9):  61%|██████    | 61/100 [00:12<00:18,  2.16it/s]
# Rank steps (Trial 9):  62%|██████▏   | 62/100 [00:13<00:19,  1.93it/s]
# Rank steps (Trial 9):  63%|██████▎   | 63/100 [00:14<00:20,  1.78it/s]
# Rank steps (Trial 9):  64%|██████▍   | 64/100 [00:14<00:21,  1.68it/s]
# Rank steps (Trial 9):  65%|██████▌   | 65/100 [00:15<00:21,  1.60it/s]
# Rank steps (Trial 9):  66%|██████▌   | 66/100 [00:16<00:21,  1.58it/s]
# Rank steps (Trial 9):  67%|██████▋   | 67/100 [00:16<00:18,  1.77it/s]
# Rank steps (Trial 9):  68%|██████▊   | 68/100 [00:16<00:16,  1.94it/s]
# Rank steps (Trial 9):  69%|██████▉   | 69/100 [00:17<00:15,  2.06it/s]
# Rank steps (Trial 9):  70%|███████   | 70/100 [00:17<00:13,  2.14it/s]
# Rank steps (Trial 9):  71%|███████   | 71/100 [00:18<00:13,  2.22it/s]
# Rank steps (Trial 9):  72%|███████▏  | 72/100 [00:18<00:12,  2.25it/s]
# Rank steps (Trial 9):  73%|███████▎  | 73/100 [00:19<00:11,  2.28it/s]
# Rank steps (Trial 9):  74%|███████▍  | 74/100 [00:19<00:11,  2.23it/s]
# Rank steps (Trial 9):  75%|███████▌  | 75/100 [00:19<00:11,  2.24it/s]
# Rank steps (Trial 9):  76%|███████▌  | 76/100 [00:20<00:10,  2.26it/s]
# Rank steps (Trial 9):  77%|███████▋  | 77/100 [00:20<00:10,  2.23it/s]
# Rank steps (Trial 9):  78%|███████▊  | 78/100 [00:21<00:09,  2.23it/s]
# Rank steps (Trial 9):  79%|███████▉  | 79/100 [00:21<00:09,  2.19it/s]
# Rank steps (Trial 9):  80%|████████  | 80/100 [00:22<00:09,  2.17it/s]
# Rank steps (Trial 9):  81%|████████  | 81/100 [00:22<00:08,  2.13it/s]
# Rank steps (Trial 9):  82%|████████▏ | 82/100 [00:23<00:08,  2.12it/s]
# Rank steps (Trial 9):  83%|████████▎ | 83/100 [00:23<00:08,  2.08it/s]
# Rank steps (Trial 9):  84%|████████▍ | 84/100 [00:24<00:07,  2.04it/s]
# Rank steps (Trial 9):  85%|████████▌ | 85/100 [00:24<00:07,  2.01it/s]
# Rank steps (Trial 9):  86%|████████▌ | 86/100 [00:25<00:06,  2.01it/s]
# Rank steps (Trial 9):  87%|████████▋ | 87/100 [00:25<00:06,  1.99it/s]
# Rank steps (Trial 9):  88%|████████▊ | 88/100 [00:26<00:06,  1.80it/s]
# Rank steps (Trial 9):  89%|████████▉ | 89/100 [00:27<00:07,  1.50it/s]
# Rank steps (Trial 9):  90%|█████████ | 90/100 [00:28<00:07,  1.32it/s]
# Rank steps (Trial 9):  91%|█████████ | 91/100 [00:29<00:07,  1.22it/s]
# Rank steps (Trial 9):  92%|█████████▏| 92/100 [00:30<00:06,  1.17it/s]
# Rank steps (Trial 9):  93%|█████████▎| 93/100 [00:30<00:05,  1.31it/s]
# Rank steps (Trial 9):  94%|█████████▍| 94/100 [00:31<00:04,  1.42it/s]
# Rank steps (Trial 9):  95%|█████████▌| 95/100 [00:31<00:03,  1.52it/s]
# Rank steps (Trial 9):  96%|█████████▌| 96/100 [00:32<00:02,  1.58it/s]
# Rank steps (Trial 9):  97%|█████████▋| 97/100 [00:33<00:01,  1.64it/s]
# Rank steps (Trial 9):  98%|█████████▊| 98/100 [00:33<00:01,  1.66it/s]
# Rank steps (Trial 9):  99%|█████████▉| 99/100 [00:34<00:00,  1.69it/s]
# Rank steps (Trial 9): 100%|██████████| 100/100 [00:34<00:00,  1.70it/s]
# Trials:  90%|█████████ | 9/10 [05:15<00:35, 35.05s/it]
# Rank steps (Trial 10):   0%|          | 0/100 [00:00<?, ?it/s]
# Rank steps (Trial 10):   4%|▍         | 4/100 [00:00<00:02, 37.68it/s]
# Rank steps (Trial 10):   8%|▊         | 8/100 [00:00<00:03, 28.38it/s]
# Rank steps (Trial 10):  11%|█         | 11/100 [00:00<00:04, 21.44it/s]
# Rank steps (Trial 10):  14%|█▍        | 14/100 [00:00<00:05, 16.70it/s]
# Rank steps (Trial 10):  16%|█▌        | 16/100 [00:00<00:05, 14.64it/s]
# Rank steps (Trial 10):  18%|█▊        | 18/100 [00:01<00:06, 12.79it/s]
# Rank steps (Trial 10):  20%|██        | 20/100 [00:01<00:07, 11.27it/s]
# Rank steps (Trial 10):  22%|██▏       | 22/100 [00:01<00:08,  9.53it/s]
# Rank steps (Trial 10):  24%|██▍       | 24/100 [00:01<00:08,  8.51it/s]
# Rank steps (Trial 10):  25%|██▌       | 25/100 [00:02<00:09,  8.01it/s]
# Rank steps (Trial 10):  26%|██▌       | 26/100 [00:02<00:09,  7.55it/s]
# Rank steps (Trial 10):  27%|██▋       | 27/100 [00:02<00:10,  6.95it/s]
# Rank steps (Trial 10):  28%|██▊       | 28/100 [00:02<00:11,  6.49it/s]
# Rank steps (Trial 10):  29%|██▉       | 29/100 [00:02<00:11,  6.24it/s]
# Rank steps (Trial 10):  30%|███       | 30/100 [00:02<00:11,  6.00it/s]
# Rank steps (Trial 10):  31%|███       | 31/100 [00:03<00:11,  5.76it/s]
# Rank steps (Trial 10):  32%|███▏      | 32/100 [00:03<00:12,  5.40it/s]
# Rank steps (Trial 10):  33%|███▎      | 33/100 [00:03<00:12,  5.23it/s]
# Rank steps (Trial 10):  34%|███▍      | 34/100 [00:03<00:13,  4.95it/s]
# Rank steps (Trial 10):  35%|███▌      | 35/100 [00:04<00:13,  4.81it/s]
# Rank steps (Trial 10):  36%|███▌      | 36/100 [00:04<00:13,  4.73it/s]
# Rank steps (Trial 10):  37%|███▋      | 37/100 [00:04<00:13,  4.67it/s]
# Rank steps (Trial 10):  38%|███▊      | 38/100 [00:04<00:13,  4.49it/s]
# Rank steps (Trial 10):  39%|███▉      | 39/100 [00:04<00:13,  4.43it/s]
# Rank steps (Trial 10):  40%|████      | 40/100 [00:05<00:13,  4.32it/s]
# Rank steps (Trial 10):  41%|████      | 41/100 [00:05<00:14,  4.01it/s]
# Rank steps (Trial 10):  42%|████▏     | 42/100 [00:05<00:18,  3.22it/s]
# Rank steps (Trial 10):  43%|████▎     | 43/100 [00:06<00:20,  2.80it/s]
# Rank steps (Trial 10):  44%|████▍     | 44/100 [00:06<00:21,  2.57it/s]
# Rank steps (Trial 10):  45%|████▌     | 45/100 [00:07<00:22,  2.39it/s]
# Rank steps (Trial 10):  46%|████▌     | 46/100 [00:07<00:23,  2.26it/s]
# Rank steps (Trial 10):  47%|████▋     | 47/100 [00:08<00:24,  2.14it/s]
# Rank steps (Trial 10):  48%|████▊     | 48/100 [00:08<00:25,  2.07it/s]
# Rank steps (Trial 10):  49%|████▉     | 49/100 [00:09<00:25,  2.02it/s]
# Rank steps (Trial 10):  50%|█████     | 50/100 [00:09<00:23,  2.13it/s]
# Rank steps (Trial 10):  51%|█████     | 51/100 [00:10<00:20,  2.36it/s]
# Rank steps (Trial 10):  52%|█████▏    | 52/100 [00:10<00:18,  2.58it/s]
# Rank steps (Trial 10):  53%|█████▎    | 53/100 [00:10<00:17,  2.75it/s]
# Rank steps (Trial 10):  54%|█████▍    | 54/100 [00:11<00:16,  2.84it/s]
# Rank steps (Trial 10):  55%|█████▌    | 55/100 [00:11<00:15,  2.86it/s]
# Rank steps (Trial 10):  56%|█████▌    | 56/100 [00:11<00:15,  2.93it/s]
# Rank steps (Trial 10):  57%|█████▋    | 57/100 [00:12<00:14,  2.95it/s]
# Rank steps (Trial 10):  58%|█████▊    | 58/100 [00:12<00:14,  2.89it/s]
# Rank steps (Trial 10):  59%|█████▉    | 59/100 [00:12<00:14,  2.91it/s]
# Rank steps (Trial 10):  60%|██████    | 60/100 [00:13<00:13,  2.90it/s]
# Rank steps (Trial 10):  61%|██████    | 61/100 [00:13<00:13,  2.81it/s]
# Rank steps (Trial 10):  62%|██████▏   | 62/100 [00:13<00:13,  2.76it/s]
# Rank steps (Trial 10):  63%|██████▎   | 63/100 [00:14<00:13,  2.70it/s]
# Rank steps (Trial 10):  64%|██████▍   | 64/100 [00:14<00:13,  2.69it/s]
# Rank steps (Trial 10):  65%|██████▌   | 65/100 [00:15<00:13,  2.67it/s]
# Rank steps (Trial 10):  66%|██████▌   | 66/100 [00:15<00:13,  2.61it/s]
# Rank steps (Trial 10):  67%|██████▋   | 67/100 [00:15<00:12,  2.61it/s]
# Rank steps (Trial 10):  68%|██████▊   | 68/100 [00:16<00:12,  2.59it/s]
# Rank steps (Trial 10):  69%|██████▉   | 69/100 [00:16<00:12,  2.52it/s]
# Rank steps (Trial 10):  70%|███████   | 70/100 [00:17<00:11,  2.51it/s]
# Rank steps (Trial 10):  71%|███████   | 71/100 [00:17<00:11,  2.45it/s]
# Rank steps (Trial 10):  72%|███████▏  | 72/100 [00:17<00:11,  2.44it/s]
# Rank steps (Trial 10):  73%|███████▎  | 73/100 [00:18<00:11,  2.41it/s]
# Rank steps (Trial 10):  74%|███████▍  | 74/100 [00:18<00:11,  2.36it/s]
# Rank steps (Trial 10):  75%|███████▌  | 75/100 [00:19<00:10,  2.35it/s]
# Rank steps (Trial 10):  76%|███████▌  | 76/100 [00:19<00:10,  2.24it/s]
# Rank steps (Trial 10):  77%|███████▋  | 77/100 [00:20<00:12,  1.80it/s]
# Rank steps (Trial 10):  78%|███████▊  | 78/100 [00:21<00:13,  1.59it/s]
# Rank steps (Trial 10):  79%|███████▉  | 79/100 [00:22<00:14,  1.44it/s]
# Rank steps (Trial 10):  80%|████████  | 80/100 [00:22<00:14,  1.36it/s]
# Rank steps (Trial 10):  81%|████████  | 81/100 [00:23<00:14,  1.30it/s]
# Rank steps (Trial 10):  82%|████████▏ | 82/100 [00:24<00:12,  1.45it/s]
# Rank steps (Trial 10):  83%|████████▎ | 83/100 [00:24<00:10,  1.60it/s]
# Rank steps (Trial 10):  84%|████████▍ | 84/100 [00:25<00:09,  1.71it/s]
# Rank steps (Trial 10):  85%|████████▌ | 85/100 [00:25<00:08,  1.80it/s]
# Rank steps (Trial 10):  86%|████████▌ | 86/100 [00:26<00:07,  1.85it/s]
# Rank steps (Trial 10):  87%|████████▋ | 87/100 [00:26<00:06,  1.89it/s]
# Rank steps (Trial 10):  88%|████████▊ | 88/100 [00:27<00:06,  1.89it/s]
# Rank steps (Trial 10):  89%|████████▉ | 89/100 [00:27<00:05,  1.91it/s]
# Rank steps (Trial 10):  90%|█████████ | 90/100 [00:28<00:05,  1.90it/s]
# Rank steps (Trial 10):  91%|█████████ | 91/100 [00:28<00:04,  1.90it/s]
# Rank steps (Trial 10):  92%|█████████▏| 92/100 [00:29<00:04,  1.88it/s]
# Rank steps (Trial 10):  93%|█████████▎| 93/100 [00:29<00:03,  1.87it/s]
# Rank steps (Trial 10):  94%|█████████▍| 94/100 [00:30<00:03,  1.84it/s]
# Rank steps (Trial 10):  95%|█████████▌| 95/100 [00:31<00:02,  1.84it/s]
# Rank steps (Trial 10):  96%|█████████▌| 96/100 [00:31<00:02,  1.82it/s]
# Rank steps (Trial 10):  97%|█████████▋| 97/100 [00:32<00:01,  1.80it/s]
# Rank steps (Trial 10):  98%|█████████▊| 98/100 [00:32<00:01,  1.79it/s]
# Rank steps (Trial 10):  99%|█████████▉| 99/100 [00:33<00:00,  1.77it/s]
# Rank steps (Trial 10): 100%|██████████| 100/100 [00:33<00:00,  1.76it/s]
# Trials: 100%|██████████| 10/10 [05:49<00:00, 34.91s/it]
# Saved (with T): /content/drive/MyDrive/mbedtls_synthetic_traces/runs_CBAMB15_CBAM_20250907_173132/rank_attack_withT_b15_CBAM.png
#
# [Diagnostics]
# VK logits (min,max,mean): -27.631021 -3.4570755e-06 -14.793881
# ATT logits (min,max,mean): -6.5270743 -4.5038958 -5.5637393
# looks_like_prob(VK preds): True
# looks_like_prob(ATT preds): True

# %%
import numpy as np

# 0) Helper
def sbox_val(x):
    # your SBOX as np.array of 256
    from sca_utils import SBOX
    return SBOX[x]

# 1) Check "attack" meta: is key fixed? does pt[BYTE] vary?
pt_vals, key_vals = [], []
for _, _, pt, key in ds_att_full.unbatch().take(2000): # sample first 2k
    k = key.numpy() if key.shape==() else key.numpy()[BYTE]
    p = pt.numpy() if pt.shape==() else pt.numpy()[BYTE]
    key_vals.append(int(k))
    pt_vals.append(int(p))

key_vals = np.array(key_vals)
pt_vals = np.array(pt_vals)

print("[ATT META] BYTE =", BYTE)
print(" key unique count:", np.unique(key_vals).size, " example:", key_vals[:10])
print(" pt unique count :", np.unique(pt_vals).size, " example:", pt_vals[:10])

# 2) Compute the *true class index* for each attack trace: y* = SBOX[ pt^key ]
y_star = sbox_val(np.bitwise_xor(pt_vals, key_vals)).astype(int)

print(" y* unique count:", np.unique(y_star).size, " example:", y_star[:10])

# 3) Pull the corresponding model probability for the true class (no temperature)
# P_noT must be your attack-set probabilities:
# - if your model outputs logits, do P_noT = softmax(logits_a)
# - if it outputs probs, P_noT = logits_a (already done earlier)
P_true = P_noT[np.arange(len(y_star)), y_star]
print(" mean P(true class) (first 2k):", float(np.mean(P_true)))
print(" 25/50/75 pct:", np.percentile(P_true, [25,50,75]))

# 4) Quick attack *top-1* accuracy (first 2k) — not the final metric, just a smell test
top1 = np.argmax(P_noT[:len(y_star)], axis=1)
acc_top1 = float(np.mean(top1 == y_star))
print(" top-1 acc (first 2k):", acc_top1)

# 5) Verify BYTE/dataset alignment: does the training VAL set show similar behavior?
# (load your VK-val preds/labels already present as vk_pred (prob/logits handled before))
from sca_utils import SBOX
# vk_lab should be SBOX[pt^key] for your training VAL; just show its entropy
print("[VK VAL] labels unique:", len(np.unique(vk_lab)))
# Out:
# [ATT META] BYTE = 15
#  key unique count: 1  example: [112 112 112 112 112 112 112 112 112 112]
#  pt unique count : 256  example: [ 44 204  40 133  43 114  20  36 127  43]
#  y* unique count: 256  example: [ 74 101 106 230  57 119  67  32 118  57]
#  mean P(true class) (first 2k): 0.003912201151251793
#  25/50/75 pct: [0.00338377 0.00384283 0.00436742]
#  top-1 acc (first 2k): 0.003
# [VK VAL] labels unique: 256

# %%
# !cp /content/drive/MyDrive/mbedtls_synthetic_traces/runs_CBAMB14_CBAM_20250831_222350/final.keras /content/drive/MyDrive/mbedtls_synthetic_traces/runs_CBAMB14_CBAM_20250831_222350/best.keras
