# %% [markdown]
# # Includes & prerequisites

# %%
# !cp /content/drive/MyDrive/Colab\ Notebooks/include/tuning_utils.py /content/
# !cp /content/drive/MyDrive/Colab\ Notebooks/include/models.py /content/
# !cp /content/drive/MyDrive/Colab\ Notebooks/include/sca_utils.py /content/
# !cp /content/drive/MyDrive/Colab\ Notebooks/include/data_utils.py /content/
# !pip install keras-tuner --upgrade
# Out:
# Collecting keras-tuner
#   Downloading keras_tuner-1.4.7-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: keras in /usr/local/lib/python3.12/dist-packages (from keras-tuner) (3.10.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from keras-tuner) (25.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from keras-tuner) (2.32.4)
# Collecting kt-legacy (from keras-tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl.metadata (221 bytes)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from keras->keras-tuner) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from keras->keras-tuner) (2.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras->keras-tuner) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras->keras-tuner) (0.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from keras->keras-tuner) (3.14.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras->keras-tuner) (0.17.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.12/dist-packages (from keras->keras-tuner) (0.5.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->keras-tuner) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->keras-tuner) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->keras-tuner) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->keras-tuner) (2025.8.3)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from optree->keras->keras-tuner) (4.15.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras->keras-tuner) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras->keras-tuner) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras->keras-tuner) (0.1.2)
# Downloading keras_tuner-1.4.7-py3-none-any.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 4.3 MB/s eta 0:00:00
# Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.4.7 kt-legacy-1.0.5

# %%
from tuning_utils import CleanMemoryTuner, model_builder_synthetic_se_cnn, vgg_cbam_synthetic_builder
from models import cbam_block, vgg_cnn_cbam, cnn_squeeze_excite
from data_utils import SyntheticDataLoader

# %% [markdown]
# # Train the model with best hyperparameters on the full RPA dataset

# %%
model_config = {
    "CBAM": {
        "tuner_dir": "/content/drive/MyDrive/mbedtls_synthetic_traces/RANDOM_datasets/CBAM/hypertuning",
        "model_builder_fun": vgg_cbam_synthetic_builder,
        "model_fun": vgg_cnn_cbam
    },
    "SE": {
        "tuner_dir": "/content/drive/MyDrive/mbedtls_synthetic_traces/hyperparameter_tuning_efficient",
        "model_builder_fun": model_builder_synthetic_se_cnn,
        "model_fun": cnn_squeeze_excite
    }
}

# %%
# ----- Configuration -----

MODEL = "CBAM"
BYTE = 2

H5_FILE_PATH = f"/content/drive/MyDrive/mbedtls_synthetic_traces/RANDOM_datasets/profiling_windows/byte_{BYTE}.h5"

RUN_ROOT = "/content/drive/MyDrive/mbedtls_synthetic_traces/RANDOM_training"
BATCH_SIZE = 128
EPOCHS = 60
VALIDATION_SPLIT = 0.2
# LR = 1e-3
SEED = 1917

# %%
# ----- Reproducibility -----

import os, json, random, numpy as np, tensorflow as tf
os.environ["TF_DETERMINISTIC_OPS"] = "1"
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %%
# ----- Paths

from datetime import datetime
run_id = datetime.now().strftime(f"B{BYTE}_{MODEL}_%Y%m%d_%H%M%S")

RUN_DIR = f"{RUN_ROOT}/runs_{MODEL}{run_id}"
CKPT_BEST = f"{RUN_DIR}/best.keras"
LOG_JSON = f"{RUN_DIR}/config.json"
os.makedirs(RUN_DIR, exist_ok=True)

# %% [markdown]
# ## Load the training data
#
# Based on the `H5_FILE_PATH`, load the appropriate training data (in this case the RPA dataset).

# %%
h5_loader = SyntheticDataLoader(file_path=H5_FILE_PATH)
ds_train, ds_full_val, INPUT_DIM, train_size, val_size = h5_loader.create_dataset(
    window_index=0,
    batch_size=BATCH_SIZE,
    val_split=VALIDATION_SPLIT
)
# Out:
# Dataset created from 'byte_2.h5':
#   - Total samples: 25001
#   - Training samples: 20001
#   - Validation samples: 5000

# %%
ds_val_for_fit = ds_full_val.map(lambda trace, label, pt, key: (trace, label))

# %% [markdown]
# ## Load the model from tuning directory
#
# Get the best hyperparameters from the tuning runs on a random dataset and rebuild the model.

# %%
tuner = CleanMemoryTuner(
    hypermodel=lambda hp: model_config[MODEL]['model_builder_fun'](
            hp,
            model_fun=model_config[MODEL]['model_fun'],
            input_dim=INPUT_DIM
        ),
    objective="val_accuracy",
    max_trials=10,
    executions_per_trial=1,
    directory=model_config[MODEL]['tuner_dir'],
    project_name=f"tuning_byte_{BYTE}",
    overwrite=False
)
# Out:
# Reloading Tuner from /content/drive/MyDrive/mbedtls_synthetic_traces/RANDOM_datasets/CBAM/hypertuning/tuning_byte_2/tuner0.json

# %%
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
print(f"best_hps: {best_hps.values}")
model = tuner.hypermodel.build(best_hps)
# Out:
# best_hps: {'filter_scale': 1.5, 'dropout': 0.3, 'cbam_ratio': 32, 'batch_normalize': True, 'optimizer': 'adam', 'learning_rate': 5e-05}

# %%
model.summary()
# Out:
# Model: "cbam_model"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 701, 1)    │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_conv1        │ (None, 701, 96)   │      1,152 │ input_layer[0][0] │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 701, 96)   │        384 │ block1_conv1[0][… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_pool1        │ (None, 350, 96)   │          0 │ batch_normalizat… │
# │ (AveragePooling1D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2_conv1        │ (None, 350, 192)  │    202,944 │ block1_pool1[0][… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 350, 192)  │        768 │ block2_conv1[0][… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 192)       │          0 │ batch_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 192)       │          0 │ batch_normalizat… │
# │ (GlobalMaxPooling1… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 6)         │      1,158 │ global_average_p… │
# │                     │                   │            │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 192)       │      1,344 │ dense[0][0],      │
# │                     │                   │            │ dense[1][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 192)       │          0 │ dense_1[0][0],    │
# │                     │                   │            │ dense_1[1][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation          │ (None, 192)       │          0 │ add[0][0]         │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 1, 192)    │          0 │ activation[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 350, 192)  │          0 │ batch_normalizat… │
# │                     │                   │            │ reshape[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ channelwise_pool    │ (None, 350, 2)    │          0 │ multiply[0][0]    │
# │ (ChannelwisePool)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d (Conv1D)     │ (None, 350, 1)    │         14 │ channelwise_pool… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 350, 192)  │          0 │ multiply[0][0],   │
# │ (Multiply)          │                   │            │ conv1d[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_pool2        │ (None, 175, 192)  │          0 │ multiply_1[0][0]  │
# │ (AveragePooling1D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3_conv1        │ (None, 175, 384)  │    811,392 │ block1_pool2[0][… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 175, 384)  │      1,536 │ block3_conv1[0][… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_pool3        │ (None, 87, 384)   │          0 │ batch_normalizat… │
# │ (AveragePooling1D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4_conv1        │ (None, 87, 768)   │  3,244,800 │ block1_pool3[0][… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 87, 768)   │      3,072 │ block4_conv1[0][… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_pool4        │ (None, 43, 768)   │          0 │ batch_normalizat… │
# │ (AveragePooling1D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5_conv1        │ (None, 43, 768)   │  6,488,832 │ block1_pool4[0][… │
# │ (Conv1D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 43, 768)   │      3,072 │ block5_conv1[0][… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 768)       │          0 │ batch_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_max_pooling… │ (None, 768)       │          0 │ batch_normalizat… │
# │ (GlobalMaxPooling1… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 24)        │     18,456 │ global_average_p… │
# │                     │                   │            │ global_max_pooli… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 768)       │     19,200 │ dense_2[0][0],    │
# │                     │                   │            │ dense_2[1][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 768)       │          0 │ dense_3[0][0],    │
# │                     │                   │            │ dense_3[1][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_1        │ (None, 768)       │          0 │ add_1[0][0]       │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_1 (Reshape) │ (None, 1, 768)    │          0 │ activation_1[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_2          │ (None, 43, 768)   │          0 │ batch_normalizat… │
# │ (Multiply)          │                   │            │ reshape_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ channelwise_pool_1  │ (None, 43, 2)     │          0 │ multiply_2[0][0]  │
# │ (ChannelwisePool)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_1 (Conv1D)   │ (None, 43, 1)     │         14 │ channelwise_pool… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_3          │ (None, 43, 768)   │          0 │ multiply_2[0][0], │
# │ (Multiply)          │                   │            │ conv1d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1_pool5        │ (None, 21, 768)   │          0 │ multiply_3[0][0]  │
# │ (AveragePooling1D)  │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 16128)     │          0 │ block1_pool5[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fc1 (Dense)         │ (None, 4096)      │ 66,064,384 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 4096)      │          0 │ fc1[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fc2 (Dense)         │ (None, 4096)      │ 16,781,312 │ dropout[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_1 (Dropout) │ (None, 4096)      │          0 │ fc2[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ predictions (Dense) │ (None, 256)       │  1,048,832 │ dropout_1[0][0]   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 94,692,666 (361.22 MB)
#  Trainable params: 94,688,250 (361.21 MB)
#  Non-trainable params: 4,416 (17.25 KB)

# %%
print(model.optimizer.learning_rate)
# Out:
# <Variable path=adam/learning_rate, shape=(), dtype=float32, value=4.999999873689376e-05>

# %% [markdown]
# ## Run the training

# %%
csv_log = tf.keras.callbacks.CSVLogger(f"{RUN_DIR}/train_log.csv")
cbs = [
    tf.keras.callbacks.ModelCheckpoint(CKPT_BEST, monitor="val_loss", save_best_only=True),
    tf.keras.callbacks.EarlyStopping(monitor="val_loss", patience=15, restore_best_weights=True),
    csv_log
]

# %%
print("\n--- Starting Model Training on HDF5 Data ---")
history = model.fit(
    ds_train,
    epochs=EPOCHS,
    validation_data=ds_val_for_fit,
    callbacks=cbs,
    verbose=2
)
# Out:
# --- Starting Model Training on HDF5 Data ---
# Epoch 1/60
# /usr/local/lib/python3.12/dist-packages/keras/src/trainers/epoch_iterator.py:160: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 157/157 - 55s - 348ms/step - accuracy: 0.0039 - loss: 5.5462 - val_accuracy: 0.0050 - val_loss: 5.5471
# Epoch 2/60
# 157/157 - 43s - 272ms/step - accuracy: 0.0047 - loss: 5.5425 - val_accuracy: 0.0060 - val_loss: 5.5470
# Epoch 3/60
# 157/157 - 63s - 401ms/step - accuracy: 0.0055 - loss: 5.5396 - val_accuracy: 0.0060 - val_loss: 5.5300
# Epoch 4/60
# 157/157 - 63s - 402ms/step - accuracy: 0.0059 - loss: 5.5333 - val_accuracy: 0.0088 - val_loss: 5.5122
# Epoch 5/60
# 157/157 - 63s - 402ms/step - accuracy: 0.0070 - loss: 5.5171 - val_accuracy: 0.0148 - val_loss: 5.4795
# Epoch 6/60
# 157/157 - 63s - 400ms/step - accuracy: 0.0121 - loss: 5.4723 - val_accuracy: 0.0278 - val_loss: 5.3852
# Epoch 7/60
# 157/157 - 63s - 400ms/step - accuracy: 0.0230 - loss: 5.3549 - val_accuracy: 0.0660 - val_loss: 5.1456
# Epoch 8/60
# 157/157 - 63s - 400ms/step - accuracy: 0.0533 - loss: 5.0676 - val_accuracy: 0.2014 - val_loss: 4.6432
# Epoch 9/60
# 157/157 - 63s - 401ms/step - accuracy: 0.1489 - loss: 4.4459 - val_accuracy: 0.4410 - val_loss: 3.6662
# Epoch 10/60
# 157/157 - 65s - 414ms/step - accuracy: 0.3613 - loss: 3.3143 - val_accuracy: 0.6736 - val_loss: 2.3291
# Epoch 11/60
# 157/157 - 63s - 403ms/step - accuracy: 0.6626 - loss: 1.8641 - val_accuracy: 0.8642 - val_loss: 1.0414
# Epoch 12/60
# 157/157 - 63s - 404ms/step - accuracy: 0.8821 - loss: 0.7653 - val_accuracy: 0.9522 - val_loss: 0.3983
# Epoch 13/60
# 157/157 - 63s - 400ms/step - accuracy: 0.9596 - loss: 0.3071 - val_accuracy: 0.9796 - val_loss: 0.1554
# Epoch 14/60
# 157/157 - 63s - 401ms/step - accuracy: 0.9839 - loss: 0.1401 - val_accuracy: 0.9946 - val_loss: 0.0575
# Epoch 15/60
# 157/157 - 63s - 400ms/step - accuracy: 0.9946 - loss: 0.0666 - val_accuracy: 0.9974 - val_loss: 0.0280
# Epoch 16/60
# 157/157 - 63s - 401ms/step - accuracy: 0.9978 - loss: 0.0346 - val_accuracy: 0.9980 - val_loss: 0.0168
# Epoch 17/60
# 157/157 - 63s - 401ms/step - accuracy: 0.9987 - loss: 0.0227 - val_accuracy: 0.9988 - val_loss: 0.0095
# Epoch 18/60
# 157/157 - 63s - 399ms/step - accuracy: 0.9991 - loss: 0.0170 - val_accuracy: 0.9998 - val_loss: 0.0029
# Epoch 19/60
# 157/157 - 58s - 371ms/step - accuracy: 0.9993 - loss: 0.0124 - val_accuracy: 0.9998 - val_loss: 0.0029
# Epoch 20/60
# 157/157 - 41s - 260ms/step - accuracy: 0.9998 - loss: 0.0086 - val_accuracy: 0.9998 - val_loss: 0.0023
# Epoch 21/60
# 157/157 - 63s - 400ms/step - accuracy: 0.9999 - loss: 0.0068 - val_accuracy: 1.0000 - val_loss: 7.7225e-04
# Epoch 22/60
# 157/157 - 63s - 400ms/step - accuracy: 0.9999 - loss: 0.0053 - val_accuracy: 1.0000 - val_loss: 4.9777e-04
# Epoch 23/60
# 157/157 - 63s - 399ms/step - accuracy: 0.9999 - loss: 0.0046 - val_accuracy: 1.0000 - val_loss: 4.0170e-04
# Epoch 24/60
# 157/157 - 63s - 399ms/step - accuracy: 0.9999 - loss: 0.0039 - val_accuracy: 1.0000 - val_loss: 3.9418e-04
# Epoch 25/60
# 157/157 - 63s - 402ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 1.0000 - val_loss: 2.9735e-04
# Epoch 26/60
# 157/157 - 63s - 399ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 1.0000 - val_loss: 2.5194e-04
# Epoch 27/60
# 157/157 - 63s - 400ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 1.0000 - val_loss: 2.1610e-04
# Epoch 28/60
# 157/157 - 63s - 401ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 1.6566e-04
# Epoch 29/60
# 157/157 - 58s - 369ms/step - accuracy: 1.0000 - loss: 0.0020 - val_accuracy: 1.0000 - val_loss: 2.1330e-04
# Epoch 30/60
# 157/157 - 36s - 229ms/step - accuracy: 0.9999 - loss: 0.0024 - val_accuracy: 1.0000 - val_loss: 1.6996e-04
# Epoch 31/60
# 157/157 - 41s - 260ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 1.0000 - val_loss: 1.6318e-04
# Epoch 32/60
# 157/157 - 63s - 401ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 1.0000 - val_loss: 1.1024e-04
# Epoch 33/60
# 157/157 - 63s - 400ms/step - accuracy: 1.0000 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 9.7391e-05
# Epoch 34/60
# 157/157 - 63s - 401ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 8.1586e-05
# Epoch 35/60
# 157/157 - 58s - 368ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 9.1828e-05
# Epoch 36/60
# 157/157 - 41s - 260ms/step - accuracy: 1.0000 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 6.6988e-05
# Epoch 37/60
# 157/157 - 58s - 368ms/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 1.0295e-04
# Epoch 38/60
# 157/157 - 36s - 227ms/step - accuracy: 0.9999 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 2.3657e-04
# Epoch 39/60
# 157/157 - 36s - 227ms/step - accuracy: 0.9999 - loss: 0.0021 - val_accuracy: 1.0000 - val_loss: 1.2403e-04
# Epoch 40/60
# 157/157 - 36s - 230ms/step - accuracy: 0.9999 - loss: 0.0030 - val_accuracy: 1.0000 - val_loss: 1.7968e-04
# Epoch 41/60
# 157/157 - 36s - 229ms/step - accuracy: 0.9993 - loss: 0.0095 - val_accuracy: 0.9994 - val_loss: 0.0166
# Epoch 42/60
# 157/157 - 36s - 230ms/step - accuracy: 0.9363 - loss: 0.3064 - val_accuracy: 0.9926 - val_loss: 0.0604
# Epoch 43/60
# 157/157 - 36s - 228ms/step - accuracy: 0.9804 - loss: 0.1020 - val_accuracy: 0.9990 - val_loss: 0.0135
# Epoch 44/60
# 157/157 - 36s - 229ms/step - accuracy: 0.9952 - loss: 0.0309 - val_accuracy: 0.9996 - val_loss: 0.0037
# Epoch 45/60
# 157/157 - 36s - 229ms/step - accuracy: 0.9980 - loss: 0.0150 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 46/60
# 157/157 - 36s - 228ms/step - accuracy: 0.9993 - loss: 0.0073 - val_accuracy: 1.0000 - val_loss: 9.6502e-04
# Epoch 47/60
# 157/157 - 36s - 229ms/step - accuracy: 0.9995 - loss: 0.0055 - val_accuracy: 1.0000 - val_loss: 3.9680e-04
# Epoch 48/60
# 157/157 - 36s - 230ms/step - accuracy: 0.9998 - loss: 0.0030 - val_accuracy: 1.0000 - val_loss: 3.2496e-04
# Epoch 49/60
# 157/157 - 36s - 230ms/step - accuracy: 0.9999 - loss: 0.0022 - val_accuracy: 1.0000 - val_loss: 9.5886e-05
# Epoch 50/60
# 157/157 - 36s - 229ms/step - accuracy: 0.9998 - loss: 0.0020 - val_accuracy: 1.0000 - val_loss: 1.1223e-04
# Epoch 51/60
# 157/157 - 36s - 229ms/step - accuracy: 0.9999 - loss: 0.0023 - val_accuracy: 1.0000 - val_loss: 8.7534e-05

# %%
model.save(f"{RUN_DIR}/final.keras")

# %%
print([l.numpy() for _, l in ds_train.unbatch().batch(10)])
# Out:
# [array([  5,  96,  91,  44, 200,  83,  69,   6, 236, 221], dtype=int32), array([165, 136, 216, 215,  77, 199, 200, 177, 225, 202], dtype=int32), array([  8,  33, 195, 175, 206, 148,  77, 142, 106,  22], dtype=int32), array([154,  35,  68, 108, 200,  91, 227, 162, 171,   7], dtype=int32), array([  0, 176, 205, 127,  95, 150, 193, 151,   9, 238], dtype=int32), array([ 38,  54, 196,   8, 156,  24, 144, 247, 124, 140], dtype=int32), array([236, 194,  98, 251, 249, 234, 240, 243, 235,  88], dtype=int32), array([105,  98,  71, 147,  34,  94,  13, 142,  30,  32], dtype=int32), array([ 17, 152, 214,  76, 166, 164,  42,  31, 106,  93], dtype=int32), array([ 13,  42, 222,  74, 131, 241, 121,  39, 254,  10], dtype=int32), array([  8, 161, 239,  84,  41, 107,  33, 127, 101,   1], dtype=int32), array([ 19, 173,   3,  90, 228, 106, 148,  71, 185,  87], dtype=int32), array([ 28, 247, 160, 112, 167,  65, 124, 112,  49, 224], dtype=int32), array([  3, 195, 107, 165, 116, 217,  90, 226, 220, 197], dtype=int32), array([ 25, 224,  59, 135, 190, 123,  39, 226, 175, 191], dtype=int32), array([ 32, 157, 112, 185,  13, 173, 202, 118, 213,  43], dtype=int32), array([ 88,  18, 118, 199,  94,  87,   4, 242,  11, 113], dtype=int32), array([139, 169,  88,   0, 104, 176,  42, 194, 123, 176], dtype=int32), array([141,   5, 249, 165, 163, 199, 113,  91, 146, 246], dtype=int32), array([  4,  77, 128, 159,  61,   9,  99,  23, 158,  28], dtype=int32), array([ 41, 128, 198, 242,  23,  36, 228, 192, 241,   4], dtype=int32), array([168, 231,  67,  35,  32,  83, 248, 131,  81, 114], dtype=int32), array([ 23, 177,  23, 235, 230, 167,  61, 122,  16,  85], dtype=int32), array([103,  69, 205, 194,  45, 212, 242, 148,  41, 198], dtype=int32), array([ 27, 175, 101,  54, 165, 118,  13,  22, 162, 156], dtype=int32), array([117,  72,  26,  46, 204, 181, 243,  15, 121,  35], dtype=int32), array([189, 129,  27,  65,  11, 191, 104, 226, 173,  51], dtype=int32), array([ 95, 185, 133, 230, 165, 124,  86,  54, 132,   6], dtype=int32), array([190,  73, 148,   4, 193, 234,  32, 212, 119, 155], dtype=int32), array([238, 239,   7, 246, 240, 171, 178,  82, 201, 103], dtype=int32), array([  4, 162, 230, 243, 114, 183,  77, 173, 222, 127], dtype=int32), array([201, 174, 226,   9,  27, 129, 100, 246, 209,  92], dtype=int32), array([ 49, 121, 194, 111, 146,  22, 227,  93,  40,  24], dtype=int32), array([104, 250,  90, 160, 230, 107,  69,  73, 146,  93], dtype=int32), array([ 24,   6,  77,  98, 201, 128,  92, 192, 133, 216], dtype=int32), array([218,  64, 165, 161, 176, 109, 135, 236, 192, 240], dtype=int32), array([253,  10, 190, 233, 212, 225,  81, 162, 113, 147], dtype=int32), array([ 69, 117,  25,  27,  40, 174,  30, 166, 228,  57], dtype=int32), array([171,  99,  42, 134,  14, 193, 225, 110,  96, 248], dtype=int32), array([ 95,  99,  68, 186, 253,  84, 100, 102, 208,  19], dtype=int32), array([ 50,  29, 109, 251,  37, 185, 214, 201,   7, 240], dtype=int32), array([138,  73, 201, 122, 121,  40,   6, 204, 230,  98], dtype=int32), array([171, 155, 165,  88,  96, 228,  28, 113,  32, 105], dtype=int32), array([127, 131, 214, 158, 123,  40, 250, 122, 218,  77], dtype=int32), array([146, 251,  97,  43, 106, 143,  81,  47, 182, 222], dtype=int32), array([ 13,  55, 204, 140, 206, 101, 148, 115,  21,  68], dtype=int32), array([ 48, 123, 217,  23, 122, 111, 235, 107,   3, 179], dtype=int32), array([200, 195, 163, 208, 172, 210,  65, 246, 159, 196], dtype=int32), array([112, 203,  58, 113, 184, 197,  40,  27,  28, 235], dtype=int32), array([ 57,  65, 237, 240, 246,  19, 122,  15, 244, 135], dtype=int32), array([168,  29, 228,  51, 172,  85, 184, 155, 237, 225], dtype=int32), array([191, 221,  65, 185,  91, 107,  72, 200, 134, 109], dtype=int32), array([207, 161, 235,  43,  28,  54, 117, 154, 205, 187], dtype=int32), array([  9,  67,  87, 177,   2, 248, 146,  27,  55, 104], dtype=int32), array([ 37,  24, 240,  80, 122, 143, 115,  13, 231, 248], dtype=int32), array([158, 254,  97, 120,  92, 105, 25 ...

# %%
ds_val_X = ds_full_val.map(lambda trace,label,pt,key: trace)
raw = model.predict(ds_val_X, verbose=0)

FROM_LOGITS = True

if FROM_LOGITS:
  val_logits = raw
else:
  val_logits = tf.math.log(tf.clip_by_value(raw, 1e-12, 1.0)).numpy()

val_labels = np.array([int(lbl.numpy()) for _, lbl, _, _ in ds_full_val.unbatch()], dtype=np.int64)

np.savez(f"{RUN_DIR}/val_logits_labels.npz", logits=val_logits, labels=val_labels)
